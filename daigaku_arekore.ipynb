# %% [markdown]
# <a href="https://colab.research.google.com/github/kassymoto/daigaku/blob/master/daigaku_arekore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
import requests
from bs4 import BeautifulSoup, element
from datetime import datetime
import pandas as pd

# %%
# 大学の情報を格納するクラス
class University:
  # 検索一覧から取得できる情報
  name = ''  # 大学名
  page_url = ''  # 大学情報ページのURL soupで保持
  hensa_upper = '' # 大学のUpper偏差値
  hensa_lower = '' # 大学のLower偏差値
  prefecture = '' # 大学の所在都道府県
  manage = ''  # 私立・国立など
  
  # 個別ページから取得する情報
  star = 0  # レビューの星の数
  review_num = 0  # 口コミ件数
  review_upper = []  # 口コミ（評判）のやつ。カテゴリ、得点、順位で1ペア
  gakumon = []  # 学べる学問
  gakuhi = []  # カテゴリ、入学金、年間授業料で1ペア
  station = ''  # 最寄り駅
  gakubu = []  # 学部
  rank = []  # 口コミの順位
  
  # 検索一覧から取得できる情報
  def __init__(self, name, url, hensa, prefecture, manage):
    self.name = name
    self.page_url = requests.get(url)
    self.edit_hensa(hensa)
    self.prefecture = prefecture
    self.manage = manage
    
  # 個別ページから取得する情報
  def import_from_individual_page(self, star, review_num, review_upper, gakumon, gakuhi, station, gakubu, rank):
    self.star = star
    self.review_num = review_num
    self.review_upper =review_upper
    self.gakumon = gakumon
    self.gakuhi = gakuhi
    self.station = station
    self.gakubu = gakubu
    self.rank = rank
  
  # 偏差値が　Low - Up表記なので、これをhensa_upperとhensa_lowerに分ける
  def edit_hensa(self, hensa):
    hensa = hensa.split()
    
    if len(hensa)==1:
      if hensa[0] == '-':
        self.hensa_upper = 'None'
        self.hensa_lower = 'None'
      
      elif hensa[0] == 'BF':
        self.hensa_upper = 0
        self.hensa_lower = 0
      
      else:
        self.hensa_upper = float(hensa[0])
        self.hensa_lower = float(hensa[0])
     
    else:
      self.hensa_upper = float(hensa[-1])
      self.hensa_lower = float(hensa[0]) if hensa[0] != 'BF' else 0
  
  # デバッグ用プリンタ
  def printer(self):

    s = f'''
    大学名：{self.name}
    偏差値：{self.hensa_lower} ～ {self.hensa_upper}
    都道府県：{self.prefecture}
    形態：{self.manage}
    評価：{self.star}
    口コミ件数：{self.review_num}
    口コミ（評判）：
    {self.review_upper}
    学べる学問：
    {self.gakumon}
    学費：
    {self.gakuhi}
    最寄り駅：{self.station}
    学部：{self.gakubu}
    口コミ順位：{self.rank}
    '''
    print(s)

# %%
# urlを投げて、ページ番号指定してぬく
def get_unv_info(url, page_num):
  global unv_list
  
  mdj_url = requests.get(url + f'page={page_num}/')
  
  # みんなの大学情報のsoupを作成
  mdj_soup = BeautifulSoup(mdj_url.content, 'html.parser')
  
  # 名前、県、私立・国立、URLが含まれる
  unv_name_all = mdj_soup.find_all("div", class_='mod-listSearch-name')
  unv_hensa_all = mdj_soup.find_all("div", class_='mod-listSearch-devi')

  for unv_name, unv_hensa in zip(unv_name_all, unv_hensa_all):
    # 名前と、県/マネージを取得
    name, prefecture_and_manage = unv_name.get_text().split('\n')[1:-1]

    # 大学へのリンクを取得
    url = mdj_default + unv_name.a['href']

    # 県/マネージを分ける
    prefecture, manage = prefecture_and_manage.split('/')

    # 偏差値を取得
    hensa = unv_hensa.get_text().split('\n')[3]

    unv_list.append(University(name, url, hensa, prefecture, manage))

# %%
def get_unv_indivisual_info(unv):
  #debug
  print(unv.name)
  
  unv_soup = BeautifulSoup(unv.page_url.content, 'html.parser')

  # レビューの星の数
  try:
    star = float(unv_soup.find('p', class_='schMod-school-point').get_text())
  except AttributeError:
    star = 0.0

  # 口コミ件数
  try:
    review_num = int(unv_soup.find('p', class_='schMod-school-num').span.get_text())
  except AttributeError:
    review_num = 0
    
  # 口コミ（評判）のタイトル
  review_upper_title = unv_soup.find_all('div', class_='mod-reviewTotalv2-item')

  # 口コミ（評判）の点数
  review_upper_score = unv_soup.find_all('div', class_='mod-reviewTotalv2-score')

  # 口コミ（評判）の順位
  review_upper_rank = unv_soup.find_all('div', class_='mod-reviewTotalv2-rank')

  # 口コミ（評判）をまとめる
  review_upper = []
  for title, score, rank in zip(review_upper_title, review_upper_score, review_upper_rank):
    title = title.get_text()
    if '-' in score.get_text():
      score = 'None'
    else:
      score = float(score.get_text())
    if rank.get_text()[:-1] == '':
      rank = 'None'
    else:
      rank = int(rank.get_text()[:-1])

    unv_dict = {}
    unv_dict['title'] = title
    unv_dict['score'] = score
    unv_dict['rank'] = rank

    review_upper.append(unv_dict)

  # 学べる学問
  gakumon_all = unv_soup.find_all('div', class_='schMod-departmentList-tag')
  gakumon_list = []
  for gakumon in gakumon_all:
    gakumon_list += gakumon.get_text().split()
  gakumon_list = [g for g in gakumon_list if g != '...']


  # 学費
  gakuhi_all = unv_soup.find_all('td', class_='tx-ac')
  gakuhi_list = []
  gakuhi_dict = {}
  for i in range(len(gakuhi_all)):
    # 文系・理系・学部名
    if i == 0 or i == 3:
      gakuhi_dict['category'] = gakuhi_all[i].get_text()

    # 入学金
    if i == 1 or i == 4:
      if '～' in gakuhi_all[i].get_text():
        gakuhi_dict['enrollment_fee_lower'] = int(gakuhi_all[i].get_text().split()[0][:-1].replace(',', ''))
        gakuhi_dict['enrollment_fee_upper'] = int(gakuhi_all[i].get_text().split()[-1][:-1].replace(',', ''))
        
      elif gakuhi_all[i].get_text() == '-':
        gakuhi_dict['enrollment_fee_lower'] = 'None'
        gakuhi_dict['enrollment_fee_upper'] = 'None'
       
      else:
        gakuhi_dict['enrollment_fee_lower'] = int(gakuhi_all[i].get_text()[:-1].replace(',', ''))
        gakuhi_dict['enrollment_fee_upper'] = int(gakuhi_all[i].get_text()[:-1].replace(',', ''))
        
    # 年間授業料は下限と上限あり
    if i == 2 or i == 5:
      if gakuhi_all[i].get_text() == '-':
        gakuhi_dict['gakuhi_lower'] = 'None'
        gakuhi_dict['gakuhi_upper'] = 'None'
      else:
        gakuhi_dict['gakuhi_lower'] = int(gakuhi_all[i].get_text().split()[0][:-1].replace(',', ''))
        gakuhi_dict['gakuhi_upper'] = int(gakuhi_all[i].get_text().split()[-1][:-1].replace(',', ''))
      gakuhi_list.append(gakuhi_dict)
      gakuhi_dict = {}

  # 最寄り駅
  station_all = unv_soup.find('p', class_='schMod-school-spec')
  station = station_all.get_text().split('/')[1].replace('\n','').replace(' ','')

  # 学部
  gakubu = []
  try:
    gakubu_all = unv_soup.find('div', class_='schMod-selectPart').find_all('a')
    for g in gakubu_all:
      gakubu.append(g.get_text())
  except AttributeError:
    pass

  # 大学の口コミ順位
  try:
    rank = int(unv_soup.find('div', class_='mod-reviewTotal-rate-review').a.em.get_text())
  except AttributeError:
    rank = 'None'
  
  unv.import_from_individual_page(star, review_num, review_upper, gakumon_list, gakuhi_list, station, gakubu, rank)

# %%
# みんなの大学情報のURL　全大学検索結果のURL
first_mdj_url = 'https://www.minkou.jp/university/search/all/'

# リンクの前にくっつける用
mdj_default = 'https://www.minkou.jp'

# %%
# 結果格納リスト
unv_list = []

# ページから基本情報を取得 41まで
for i in range(1,41):
  print(f'P.{i}を取得')
  get_unv_info(first_mdj_url, i)
# Out:
# P.1を取得
# P.2を取得
# P.3を取得
# P.4を取得
# P.5を取得
# P.6を取得
# P.7を取得
# P.8を取得
# P.9を取得
# P.10を取得
# P.11を取得
# P.12を取得
# P.13を取得
# P.14を取得
# P.15を取得
# P.16を取得
# P.17を取得
# P.18を取得
# P.19を取得
# P.20を取得
# P.21を取得
# P.22を取得
# P.23を取得
# P.24を取得
# P.25を取得
# P.26を取得
# P.27を取得
# P.28を取得
# P.29を取得
# P.30を取得
# P.31を取得
# P.32を取得
# P.33を取得
# P.34を取得
# P.35を取得
# P.36を取得
# P.37を取得
# P.38を取得
# P.39を取得
# P.40を取得

# %% [markdown]
# 各大学個別ページ内のデータを抜く
# 個別ページから取得したい情報

# %%
for unv in unv_list:
  get_unv_indivisual_info(unv)
  unv.printer()
# Out:
# 愛国学園大学
#
#     大学名：愛国学園大学
#     偏差値：35.0 ～ 35.0
#     都道府県：千葉県
#     形態：私立
#     評価：2.75
#     口コミ件数：4
#     口コミ（評判）：
#     []
#     学べる学問：
#     ['文化学', '生活科学', '経営情報学']
#     学費：
#     [{'category': '人間文化学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 650000, 'gakuhi_upper': 650000}]
#     最寄り駅：四街道駅
#     学部：['人間文化学部']
#     口コミ順位：None
#
# 愛知医科大学
#
#     大学名：愛知医科大学
#     偏差値：52.5 ～ 65.0
#     都道府県：愛知県
#     形態：私立
#     評価：3.92
#     口コミ件数：29
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.63, 'rank': 290}, {'title': '研究室・ゼミ', 'score': 3.03, 'rank': 537}, {'title': '就職・進学', 'score': 3.91, 'rank': 145}, {'title': 'アクセス・立地', 'score': 2.05, 'rank': 548}, {'title': '施設・設備', 'score': 3.76, 'rank': 168}, {'title': '友人・恋愛', 'score': 3.93, 'rank': 34}, {'title': '学生生活', 'score': 3.3, 'rank': 253}]
#     学べる学問：
#     ['医学', '看護']
#     学費：
#     [{'category': '医学部', 'enrollment_fee_lower': 1500000, 'enrollment_fee_upper': 1500000, 'gakuhi_lower': 3000000, 'gakuhi_upper': 3000000}, {'category': '看護学部', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 1000000, 'gakuhi_upper': 1000000}]
#     最寄り駅：はなみずき通駅
#     学部：['医学部', '看護学部']
#     口コミ順位：115
#
# 愛知学院大学
#
#     大学名：愛知学院大学
#     偏差値：42.5 ～ 50.0
#     都道府県：愛知県
#     形態：私立
#     評価：3.77
#     口コミ件数：366
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.7, 'rank': 205}, {'title': '研究室・ゼミ', 'score': 3.72, 'rank': 181}, {'title': '就職・進学', 'score': 3.62, 'rank': 321}, {'title': 'アクセス・立地', 'score': 3.1, 'rank': 247}, {'title': '施設・設備', 'score': 3.9, 'rank': 101}, {'title': '友人・恋愛', 'score': 3.66, 'rank': 200}, {'title': '学生生活', 'score': 3.49, 'rank': 154}]
#     学べる学問：
#     ['法学', '経営学・商学', '経営学・商学', '経営情報学', '哲学・倫理・宗教', '西洋史', '考古学・文化財学', '日本史', '東洋史', '総合科学', '心理学', '医療技術', '体育・健康科学', '教職（養護教諭）', '食物・栄養学', '薬学', '歯学', '経済学']
#     学費：
#     [{'category': '文系', 'enrollment_fee_lower': 240000, 'enrollment_fee_upper': 240000, 'gakuhi_lower': 1010000, 'gakuhi_upper': 1160000}, {'category': '理系', 'enrollment_fee_lower': 240000, 'enrollment_fee_upper': 240000, 'gakuhi_lower': 1060000, 'gakuhi_upper': 1060000}]
#     最寄り駅：長久手古戦場駅
#     学部：['法学部', '経営学部', '商学部', '文学部', '総合政策学部', '心身科学部', '薬学部', '歯学部', '経済学部']
#     口コミ順位：231
#
# 愛知学泉大学
#
#     大学名：愛知学泉大学
#     偏差値：0 ～ 37.5
#     都道府県：愛知県
#     形態：私立
#     評価：3.29
#     口コミ件数：56
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.28, 'rank': 522}, {'title': '研究室・ゼミ', 'score': 3.48, 'rank': 400}, {'title': '就職・進学', 'score': 3.55, 'rank': 363}, {'title': 'アクセス・立地', 'score': 2.99, 'rank': 285}, {'title': '施設・設備', 'score': 3.04, 'rank': 508}, {'title': '友人・恋愛', 'score': 3.32, 'rank': 457}, {'title': '学生生活', 'score': 2.96, 'rank': 425}]
#     学べる学問：
#     ['教職（小学校）', '児童学', '食物・栄養学', '生活科学', '教職（幼稚園）', '経営学・商学', '社会学']
#     学費：
#     [{'category': '家政学部', 'enrollment_fee_lower': 280000, 'enrollment_fee_upper': 280000, 'gakuhi_lower': 710000, 'gakuhi_upper': 710000}, {'category': '現代マネジメント学部', 'enrollment_fee_lower': 280000, 'enrollment_fee_upper': 280000, 'gakuhi_lower': 580000, 'gakuhi_upper': 580000}]
#     最寄り駅：浄水駅
#     学部：['家政学部', '現代マネジメント学部']
#     口コミ順位：545
#
# 愛知教育大学
#
#     大学名：愛知教育大学
#     偏差値：47.5 ～ 57.5
#     都道府県：愛知県
#     形態：国立
#     評価：3.85
#     口コミ件数：294
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.52, 'rank': 73}, {'title': '研究室・ゼミ', 'score': 3.58, 'rank': 77}, {'title': '就職・進学', 'score': 3.84, 'rank': 31}, {'title': 'アクセス・立地', 'score': 1.9, 'rank': 81}, {'title': '施設・設備', 'score': 3.07, 'rank': 74}, {'title': '友人・恋愛', 'score': 3.64, 'rank': 53}, {'title': '学生生活', 'score': 3.48, 'rank': 56}]
#     学べる学問：
#     ['心理学', '教職（小学校）', '児童学', '教職（中学・高等学校）', '教職（幼稚園）']
#     学費：
#     []
#     最寄り駅：富士松駅
#     学部：['教育学部']
#     口コミ順位：50
#
# 愛知県立芸術大学
#
#     大学名：愛知県立芸術大学
#     偏差値：45.0 ～ 55.0
#     都道府県：愛知県
#     形態：公立
#     評価：4.12
#     口コミ件数：41
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.94, 'rank': 19}, {'title': '研究室・ゼミ', 'score': 3.81, 'rank': 26}, {'title': '就職・進学', 'score': 2.74, 'rank': 82}, {'title': 'アクセス・立地', 'score': 2.5, 'rank': 58}, {'title': '施設・設備', 'score': 3.29, 'rank': 62}, {'title': '友人・恋愛', 'score': 3.58, 'rank': 52}, {'title': '学生生活', 'score': 3.14, 'rank': 62}]
#     学べる学問：
#     ['考古学・文化財学', '哲学・倫理・宗教', '美術・デザイン', '芸術理論', '音楽', '芸術理論']
#     学費：
#     [{'category': '地域内', 'enrollment_fee_lower': 282000, 'enrollment_fee_upper': 282000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}, {'category': '地域外', 'enrollment_fee_lower': 282000, 'enrollment_fee_upper': 282000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}]
#     最寄り駅：芸大通駅
#     学部：['美術学部', '音楽学部']
#     口コミ順位：11
#
# 愛知県立大学
#
#     大学名：愛知県立大学
#     偏差値：50.0 ～ 55.0
#     都道府県：愛知県
#     形態：公立
#     評価：4.04
#     口コミ件数：272
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.89, 'rank': 24}, {'title': '研究室・ゼミ', 'score': 3.66, 'rank': 48}, {'title': '就職・進学', 'score': 3.62, 'rank': 60}, {'title': 'アクセス・立地', 'score': 2.27, 'rank': 68}, {'title': '施設・設備', 'score': 3.49, 'rank': 47}, {'title': '友人・恋愛', 'score': 3.54, 'rank': 57}, {'title': '学生生活', 'score': 3.23, 'rank': 57}]
#     学べる学問：
#     ['日本語', '日本文学', '文化学', '日本史', '英米語', 'フランス語', 'スペイン語（イスパニア語）', 'ドイツ語', '中国語', '情報工学', '情報科学', '児童学', '教育学', '社会福祉学', '看護']
#     学費：
#     [{'category': '地域内', 'enrollment_fee_lower': 282000, 'enrollment_fee_upper': 282000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}, {'category': '地域外', 'enrollment_fee_lower': 282000, 'enrollment_fee_upper': 282000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}]
#     最寄り駅：公園西駅
#     学部：['日本文化学部', '外国語学部', '情報科学部', '教育福祉学部', '看護学部']
#     口コミ順位：21
#
# 愛知工科大学
#
#     大学名：愛知工科大学
#     偏差値：0 ～ 35.0
#     都道府県：愛知県
#     形態：私立
#     評価：3.25
#     口コミ件数：14
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.2, 'rank': 539}, {'title': '研究室・ゼミ', 'score': 3.34, 'rank': 466}, {'title': '就職・進学', 'score': 3.06, 'rank': 544}, {'title': 'アクセス・立地', 'score': 2.88, 'rank': 335}, {'title': '施設・設備', 'score': 2.93, 'rank': 527}, {'title': '友人・恋愛', 'score': 2.39, 'rank': 570}, {'title': '学生生活', 'score': 2.92, 'rank': 436}]
#     学べる学問：
#     ['機械工学', '電気・電子・通信工学', '情報工学', '総合情報学']
#     学費：
#     [{'category': '工学部', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 840000, 'gakuhi_upper': 840000}]
#     最寄り駅：三河塩津駅
#     学部：['工学部']
#     口コミ順位：553
#
# 愛知工業大学
#
#     大学名：愛知工業大学
#     偏差値：40.0 ～ 52.5
#     都道府県：愛知県
#     形態：私立
#     評価：3.58
#     口コミ件数：124
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.41, 'rank': 479}, {'title': '研究室・ゼミ', 'score': 3.49, 'rank': 393}, {'title': '就職・進学', 'score': 3.87, 'rank': 165}, {'title': 'アクセス・立地', 'score': 2.49, 'rank': 465}, {'title': '施設・設備', 'score': 3.74, 'rank': 180}, {'title': '友人・恋愛', 'score': 3.03, 'rank': 542}, {'title': '学生生活', 'score': 3.2, 'rank': 296}]
#     学べる学問：
#     ['情報工学', '電気・電子・通信工学', '応用化学', '材料工学', '生物工学', '経営学・商学', '経営情報学', '情報工学', '映像']
#     学費：
#     [{'category': '工学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 870000, 'gakuhi_upper': 870000}, {'category': '経営学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 720000, 'gakuhi_upper': 720000}]
#     最寄り駅：八草駅
#     学部：['工学部', '経営学部', '情報科学部']
#     口コミ順位：407
#
# 愛知産業大学
#
#     大学名：愛知産業大学
#     偏差値：0 ～ 42.5
#     都道府県：愛知県
#     形態：私立
#     評価：3.99
#     口コミ件数：16
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 4.16, 'rank': 11}, {'title': '研究室・ゼミ', 'score': 3.88, 'rank': 60}, {'title': '就職・進学', 'score': 3.18, 'rank': 529}, {'title': 'アクセス・立地', 'score': 2.72, 'rank': 388}, {'title': '施設・設備', 'score': 3.73, 'rank': 191}, {'title': '友人・恋愛', 'score': 3.82, 'rank': 73}, {'title': '学生生活', 'score': 3.0, 'rank': 407}]
#     学べる学問：
#     ['住居学', '美術・デザイン', 'デザイン工学', '映像', '建築・土木・環境工学', '経営学・商学', '体育・健康科学', '生活科学']
#     学費：
#     [{'category': '造形学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 780000, 'gakuhi_upper': 780000}, {'category': '経営学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 640000, 'gakuhi_upper': 640000}]
#     最寄り駅：藤川駅
#     学部：['造形学部', '経営学部']
#     口コミ順位：77
#
# 愛知淑徳大学
#
#     大学名：愛知淑徳大学
#     偏差値：40.0 ～ 50.0
#     都道府県：愛知県
#     形態：私立
#     評価：3.79
#     口コミ件数：480
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.68, 'rank': 231}, {'title': '研究室・ゼミ', 'score': 3.71, 'rank': 188}, {'title': '就職・進学', 'score': 3.64, 'rank': 307}, {'title': 'アクセス・立地', 'score': 2.9, 'rank': 321}, {'title': '施設・設備', 'score': 3.74, 'rank': 175}, {'title': '友人・恋愛', 'score': 3.57, 'rank': 281}, {'title': '学生生活', 'score': 3.43, 'rank': 177}]
#     学べる学問：
#     ['日本文学', '英米語', '外国文学', '教職（小学校）', '教職（特別支援教育）', '経営学・商学', '経営情報学', '文化学', '経営学・商学', '観光学', '国際関係学', '英米語', '総合情報学', '心理学', '建築・土木・環境工学', '映像', 'その他芸術', '医療技術', '体育・健康科学', '保健', '食物・栄養学', '社会福祉学', '児童学', '教職（幼稚園）', '英米語']
#     学費：
#     [{'category': '文系', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 760000, 'gakuhi_upper': 860000}, {'category': '理系', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 760000, 'gakuhi_upper': 760000}]
#     最寄り駅：杁ヶ池公園駅
#     学部：['文学部', 'ビジネス学部', '交流文化学部', '人間情報学部', '心理学部', '創造表現学部', '健康医療科学部', '福祉貢献学部', 'グローバル・コミュニケーション学部']
#     口コミ順位：215
#
# 愛知大学
#
#     大学名：愛知大学
#     偏差値：47.5 ～ 55.0
#     都道府県：愛知県
#     形態：私立
#     評価：3.82
#     口コミ件数：466
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.63, 'rank': 283}, {'title': '研究室・ゼミ', 'score': 3.66, 'rank': 241}, {'title': '就職・進学', 'score': 3.77, 'rank': 213}, {'title': 'アクセス・立地', 'score': 3.88, 'rank': 78}, {'title': '施設・設備', 'score': 3.68, 'rank': 217}, {'title': '友人・恋愛', 'score': 3.65, 'rank': 206}, {'title': '学生生活', 'score': 3.57, 'rank': 108}]
#     学べる学問：
#     ['経済学', '国際関係学', '地理学', '西洋史', '哲学・倫理・宗教', '文化学', '日本史', '英米語', '文化学', '経営学・商学', '国際関係学', '中国語', '法学', '経営学・商学', '国際関係学', '経営情報学', '文化学', '政治学', '経済学', '体育・健康科学', '総合科学']
#     学費：
#     [{'category': '文系', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 720000, 'gakuhi_upper': 780000}]
#     最寄り駅：愛知大学前駅
#     学部：['経済学部', '文学部', '国際コミュニケーション学部', '現代中国学部', '法学部', '経営学部', '地域政策学部']
#     口コミ順位：184
#
# 愛知東邦大学
#
#     大学名：愛知東邦大学
#     偏差値：35.0 ～ 35.0
#     都道府県：愛知県
#     形態：私立
#     評価：3.46
#     口コミ件数：27
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.34, 'rank': 508}, {'title': '研究室・ゼミ', 'score': 3.54, 'rank': 361}, {'title': '就職・進学', 'score': 3.47, 'rank': 425}, {'title': 'アクセス・立地', 'score': 2.96, 'rank': 298}, {'title': '施設・設備', 'score': 3.67, 'rank': 224}, {'title': '友人・恋愛', 'score': 3.57, 'rank': 290}, {'title': '学生生活', 'score': 3.54, 'rank': 131}]
#     学べる学問：
#     ['経営学・商学', '観光学', '体育・健康科学', '国際関係学', '社会福祉学', '心理学', '体育・健康科学', '教職（小学校）', '児童学', '教職（幼稚園）']
#     学費：
#     [{'category': '経営学部', 'enrollment_fee_lower': 280000, 'enrollment_fee_upper': 280000, 'gakuhi_lower': 650000, 'gakuhi_upper': 740000}, {'category': '人間健康学部', 'enrollment_fee_lower': 280000, 'enrollment_fee_upper': 280000, 'gakuhi_lower': 700000, 'gakuhi_upper': 700000}]
#     最寄り駅：星ヶ丘駅
#     学部：['経営学部', '人間健康学部', '教育学部']
#     口コミ順位：485
#
# 愛知文教大学
#
#     大学名：愛知文教大学
#     偏差値：0 ～ 0
#     都道府県：愛知県
#     形態：私立
#     評価：3.0
#     口コミ件数：2
#     口コミ（評判）：
#     []
#     学べる学問：
#     ['文化学', '英米語', '中国語']
#     学費：
#     [{'category': '人文学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 780000, 'gakuhi_upper': 780000}]
#     最寄り駅：桃花台東駅
#     学部：['人文学部']
#     口コミ順位：None
#
# 愛知みずほ大学
#
#     大学名：愛知みずほ大学
#     偏差値：0 ～ 0
#     都道府県：愛知県
#     形態：私立
#     評価：3.13
#     口コミ件数：16
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 2.86, 'rank': 568}, {'title': '研究室・ゼミ', 'score': 2.6, 'rank': 563}, {'title': '就職・進学', 'score': 3.58, 'rank': 341}, {'title': 'アクセス・立地', 'score': 3.57, 'rank': 128}, {'title': '施設・設備', 'score': 3.46, 'rank': 351}, {'title': '友人・恋愛', 'score': 3.08, 'rank': 531}, {'title': '学生生活', 'score': 2.5, 'rank': 529}]
#     学べる学問：
#     ['心理学', '体育・健康科学', '教職（養護教諭）', '総合科学']
#     学費：
#     [{'category': '人間科学部', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 690000, 'gakuhi_upper': 690000}]
#     最寄り駅：猿投駅
#     学部：['人間科学部']
#     口コミ順位：570
#
# 会津大学
#
#     大学名：会津大学
#     偏差値：45.0 ～ 45.0
#     都道府県：福島県
#     形態：公立
#     評価：3.85
#     口コミ件数：30
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.54, 'rank': 67}, {'title': '研究室・ゼミ', 'score': 3.66, 'rank': 50}, {'title': '就職・進学', 'score': 3.61, 'rank': 63}, {'title': 'アクセス・立地', 'score': 2.92, 'rank': 35}, {'title': '施設・設備', 'score': 3.91, 'rank': 13}, {'title': '友人・恋愛', 'score': 2.9, 'rank': 82}, {'title': '学生生活', 'score': 3.67, 'rank': 20}]
#     学べる学問：
#     ['情報工学', '情報科学']
#     学費：
#     [{'category': '地域内', 'enrollment_fee_lower': 282000, 'enrollment_fee_upper': 282000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}, {'category': '地域外', 'enrollment_fee_lower': 564000, 'enrollment_fee_upper': 564000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}]
#     最寄り駅：会津若松駅
#     学部：['コンピュータ理工学部']
#     口コミ順位：49
#
# 藍野大学
#
#     大学名：藍野大学
#     偏差値：40.0 ～ 45.0
#     都道府県：大阪府
#     形態：私立
#     評価：3.39
#     口コミ件数：47
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.45, 'rank': 451}, {'title': '研究室・ゼミ', 'score': 3.23, 'rank': 500}, {'title': '就職・進学', 'score': 3.67, 'rank': 289}, {'title': 'アクセス・立地', 'score': 2.84, 'rank': 350}, {'title': '施設・設備', 'score': 3.13, 'rank': 487}, {'title': '友人・恋愛', 'score': 3.56, 'rank': 294}, {'title': '学生生活', 'score': 2.28, 'rank': 554}]
#     学べる学問：
#     ['看護', '理学療法', '作業療法', '医療技術']
#     学費：
#     [{'category': '医療保健学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 1150000, 'gakuhi_upper': 1150000}]
#     最寄り駅：摂津富田駅
#     学部：['医療保健学部']
#     口コミ順位：515
#
# 青森県立保健大学
#
#     大学名：青森県立保健大学
#     偏差値：0 ～ 0
#     都道府県：青森県
#     形態：公立
#     評価：4.25
#     口コミ件数：63
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 4.25, 'rank': 2}, {'title': '研究室・ゼミ', 'score': 4.05, 'rank': 4}, {'title': '就職・進学', 'score': 4.49, 'rank': 5}, {'title': 'アクセス・立地', 'score': 3.9, 'rank': 6}, {'title': '施設・設備', 'score': 4.26, 'rank': 4}, {'title': '友人・恋愛', 'score': 3.84, 'rank': 13}, {'title': '学生生活', 'score': 3.47, 'rank': 39}]
#     学べる学問：
#     ['看護', '理学療法', '社会福祉学', '食物・栄養学']
#     学費：
#     [{'category': '地域内', 'enrollment_fee_lower': 225600, 'enrollment_fee_upper': 225600, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}, {'category': '地域外', 'enrollment_fee_lower': 338400, 'enrollment_fee_upper': 338400, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}]
#     最寄り駅：小柳駅
#     学部：['健康科学部']
#     口コミ順位：3
#
# 青森公立大学
#
#     大学名：青森公立大学
#     偏差値：45.0 ～ 45.0
#     都道府県：青森県
#     形態：公立
#     評価：3.74
#     口コミ件数：80
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.68, 'rank': 48}, {'title': '研究室・ゼミ', 'score': 3.6, 'rank': 60}, {'title': '就職・進学', 'score': 3.87, 'rank': 42}, {'title': 'アクセス・立地', 'score': 1.98, 'rank': 79}, {'title': '施設・設備', 'score': 3.35, 'rank': 56}, {'title': '友人・恋愛', 'score': 3.53, 'rank': 60}, {'title': '学生生活', 'score': 3.56, 'rank': 33}]
#     学べる学問：
#     ['経営学・商学', '経済学', '政治学']
#     学費：
#     [{'category': '地域内', 'enrollment_fee_lower': 156600, 'enrollment_fee_upper': 156600, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}, {'category': '県内', 'enrollment_fee_lower': 219200, 'enrollment_fee_upper': 219200, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}]
#     最寄り駅：筒井駅
#     学部：['経営経済学部']
#     口コミ順位：64
#
# 青森大学
#
#     大学名：青森大学
#     偏差値：35.0 ～ 35.0
#     都道府県：青森県
#     形態：私立
#     評価：3.27
#     口コミ件数：47
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.31, 'rank': 518}, {'title': '研究室・ゼミ', 'score': 3.62, 'rank': 279}, {'title': '就職・進学', 'score': 3.3, 'rank': 491}, {'title': 'アクセス・立地', 'score': 2.28, 'rank': 514}, {'title': '施設・設備', 'score': 2.64, 'rank': 566}, {'title': '友人・恋愛', 'score': 3.62, 'rank': 247}, {'title': '学生生活', 'score': 3.31, 'rank': 243}]
#     学べる学問：
#     ['経営学・商学', '体育・健康科学', '経営情報学', '社会学', '社会福祉学', '薬学', '機械工学', '情報工学', '映像']
#     学費：
#     [{'category': '総合経営学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 642000, 'gakuhi_upper': 642000}, {'category': '社会学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 642000, 'gakuhi_upper': 642000}]
#     最寄り駅：筒井駅
#     学部：['総合経営学部', '社会学部', '薬学部', 'ソフトウェア情報学部']
#     口コミ順位：551
#
# 青森中央学院大学
#
#     大学名：青森中央学院大学
#     偏差値：35.0 ～ 37.5
#     都道府県：青森県
#     形態：私立
#     評価：3.46
#     口コミ件数：33
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.6, 'rank': 316}, {'title': '研究室・ゼミ', 'score': 3.93, 'rank': 39}, {'title': '就職・進学', 'score': 3.91, 'rank': 144}, {'title': 'アクセス・立地', 'score': 3.71, 'rank': 100}, {'title': '施設・設備', 'score': 3.93, 'rank': 90}, {'title': '友人・恋愛', 'score': 3.75, 'rank': 125}, {'title': '学生生活', 'score': 3.27, 'rank': 268}]
#     学べる学問：
#     ['法学', '経営学・商学', '看護']
#     学費：
#     [{'category': '経営法学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 650000, 'gakuhi_upper': 650000}, {'category': '看護学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 800000, 'gakuhi_upper': 800000}]
#     最寄り駅：筒井駅
#     学部：['経営法学部', '看護学部']
#     口コミ順位：484
#
# 青山学院大学
#
#     大学名：青山学院大学
#     偏差値：55.0 ～ 65.0
#     都道府県：東京都
#     形態：私立
#     評価：3.95
#     口コミ件数：1060
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.67, 'rank': 240}, {'title': '研究室・ゼミ', 'score': 3.73, 'rank': 171}, {'title': '就職・進学', 'score': 3.74, 'rank': 233}, {'title': 'アクセス・立地', 'score': 4.22, 'rank': 33}, {'title': '施設・設備', 'score': 3.91, 'rank': 95}, {'title': '友人・恋愛', 'score': 3.92, 'rank': 38}, {'title': '学生生活', 'score': 4.0, 'rank': 15}]
#     学べる学問：
#     ['法学', '政治学', '国際関係学', '経済学', '政治学', '経営学・商学', '英米語', '外国文学', '教職（中学・高等学校）', '文化学', 'フランス語', '政治学', '経済学', '経営学・商学', '国際関係学', '児童学', '教職（幼稚園）', '教育学', '総合情報学', '心理学', '文化学', '総合科学', '芸術理論', '数学', '物理学', '応用物理学', '化学', '電気・電子・通信工学', '総合情報学', '国際関係学', '社会学', '人間科学']
#     学費：
#     [{'category': '文系', 'enrollment_fee_lower': 160000, 'enrollment_fee_upper': 160000, 'gakuhi_lower': 813000, 'gakuhi_upper': 987000}, {'category': '理系', 'enrollment_fee_lower': 160000, 'enrollment_fee_upper': 160000, 'gakuhi_lower': 987000, 'gakuhi_upper': 1161000}]
#     最寄り駅：表参道駅
#     学部：['法学部', '経済学部', '経営学部', '文学部', '国際政治経済学部', '教育人間科学部', '総合文化政策学部', '理工学部', '社会情報学部', '地球社会共生学部', 'コミュニティ人間科学部']
#     口コミ順位：91
#
# 秋田看護福祉大学
#
#     大学名：秋田看護福祉大学
#     偏差値：35.0 ～ 37.5
#     都道府県：秋田県
#     形態：私立
#     評価：4.14
#     口コミ件数：21
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.88, 'rank': 78}, {'title': '研究室・ゼミ', 'score': 3.99, 'rank': 20}, {'title': '就職・進学', 'score': 4.2, 'rank': 43}, {'title': 'アクセス・立地', 'score': 3.4, 'rank': 164}, {'title': '施設・設備', 'score': 3.57, 'rank': 294}, {'title': '友人・恋愛', 'score': 3.78, 'rank': 100}, {'title': '学生生活', 'score': 3.19, 'rank': 311}]
#     学べる学問：
#     ['看護', '社会福祉学']
#     学費：
#     [{'category': '看護福祉学部', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 650000, 'gakuhi_upper': 750000}]
#     最寄り駅：大館駅
#     学部：['看護福祉学部']
#     口コミ順位：24
#
# 秋田県立大学
#
#     大学名：秋田県立大学
#     偏差値：42.5 ～ 47.5
#     都道府県：秋田県
#     形態：公立
#     評価：3.75
#     口コミ件数：70
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.7, 'rank': 46}, {'title': '研究室・ゼミ', 'score': 3.81, 'rank': 25}, {'title': '就職・進学', 'score': 4.06, 'rank': 29}, {'title': 'アクセス・立地', 'score': 2.41, 'rank': 61}, {'title': '施設・設備', 'score': 4.01, 'rank': 11}, {'title': '友人・恋愛', 'score': 3.44, 'rank': 73}, {'title': '学生生活', 'score': 3.44, 'rank': 42}]
#     学べる学問：
#     ['機械工学', '電気・電子・通信工学', '情報科学', '建築・土木・環境工学', '経営工学', '生物工学', '農芸化学', '農学', '農業経済学・農業経営学']
#     学費：
#     [{'category': '地域内', 'enrollment_fee_lower': 282000, 'enrollment_fee_upper': 282000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}, {'category': '地域外', 'enrollment_fee_lower': 423000, 'enrollment_fee_upper': 423000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}]
#     最寄り駅：追分駅
#     学部：['システム科学技術学部', '生物資源科学部']
#     口コミ順位：63
#
# 秋田公立美術大学
#
#     大学名：秋田公立美術大学
#     偏差値：0 ～ 0
#     都道府県：秋田県
#     形態：公立
#     評価：3.47
#     口コミ件数：14
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.51, 'rank': 72}, {'title': '研究室・ゼミ', 'score': 3.16, 'rank': 83}, {'title': '就職・進学', 'score': 3.45, 'rank': 69}, {'title': 'アクセス・立地', 'score': 3.52, 'rank': 13}, {'title': '施設・設備', 'score': 3.52, 'rank': 44}, {'title': '友人・恋愛', 'score': 3.08, 'rank': 79}, {'title': '学生生活', 'score': 2.71, 'rank': 76}]
#     学べる学問：
#     ['美術・デザイン']
#     学費：
#     [{'category': '地域内', 'enrollment_fee_lower': 282000, 'enrollment_fee_upper': 282000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}, {'category': '地域外', 'enrollment_fee_lower': 423000, 'enrollment_fee_upper': 423000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}]
#     最寄り駅：新屋駅
#     学部：['美術学部']
#     口コミ順位：80
#
# 秋田大学
#
#     大学名：秋田大学
#     偏差値：42.5 ～ 65.0
#     都道府県：秋田県
#     形態：国立
#     評価：3.73
#     口コミ件数：236
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.67, 'rank': 43}, {'title': '研究室・ゼミ', 'score': 3.59, 'rank': 75}, {'title': '就職・進学', 'score': 3.83, 'rank': 34}, {'title': 'アクセス・立地', 'score': 3.36, 'rank': 27}, {'title': '施設・設備', 'score': 3.43, 'rank': 52}, {'title': '友人・恋愛', 'score': 3.8, 'rank': 18}, {'title': '学生生活', 'score': 3.67, 'rank': 37}]
#     学べる学問：
#     ['生物工学', '応用化学', '材料工学', '数学', '情報工学', '教職（小学校）', '児童学', '教職（中学・高等学校）', '教職（幼稚園）', '教職（特別支援教育）', '医学', '看護', '理学療法', '作業療法', '国際関係学', '地球科学', '材料工学']
#     学費：
#     []
#     最寄り駅：秋田駅
#     学部：['理工学部', '教育文化学部', '医学部', '国際資源学部']
#     口コミ順位：75
#
# 旭川医科大学
#
#     大学名：旭川医科大学
#     偏差値：0 ～ 65.0
#     都道府県：北海道
#     形態：国立
#     評価：3.87
#     口コミ件数：59
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.49, 'rank': 78}, {'title': '研究室・ゼミ', 'score': 3.18, 'rank': 83}, {'title': '就職・進学', 'score': 3.86, 'rank': 30}, {'title': 'アクセス・立地', 'score': 2.76, 'rank': 54}, {'title': '施設・設備', 'score': 3.69, 'rank': 20}, {'title': '友人・恋愛', 'score': 3.67, 'rank': 48}, {'title': '学生生活', 'score': 4.37, 'rank': 1}]
#     学べる学問：
#     ['医学', '看護']
#     学費：
#     []
#     最寄り駅：西御料駅
#     学部：['医学部']
#     口コミ順位：47
#
# 旭川大学
#
#     大学名：旭川大学
#     偏差値：0 ～ 35.0
#     都道府県：北海道
#     形態：私立
#     評価：3.64
#     口コミ件数：28
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.36, 'rank': 505}, {'title': '研究室・ゼミ', 'score': 3.24, 'rank': 496}, {'title': '就職・進学', 'score': 3.63, 'rank': 317}, {'title': 'アクセス・立地', 'score': 2.25, 'rank': 520}, {'title': '施設・設備', 'score': 3.11, 'rank': 492}, {'title': '友人・恋愛', 'score': 3.68, 'rank': 187}, {'title': '学生生活', 'score': 3.04, 'rank': 389}]
#     学べる学問：
#     ['法学', '経済学', '経営学・商学', '社会福祉学', '看護']
#     学費：
#     [{'category': '経済学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 800000, 'gakuhi_upper': 800000}, {'category': '保健福祉学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 800000, 'gakuhi_upper': 1200000}]
#     最寄り駅：永山駅
#     学部：['経済学部', '保健福祉学部']
#     口コミ順位：357
#
# 朝日大学
#
#     大学名：朝日大学
#     偏差値：35.0 ～ 40.0
#     都道府県：岐阜県
#     形態：私立
#     評価：3.71
#     口コミ件数：60
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.63, 'rank': 286}, {'title': '研究室・ゼミ', 'score': 3.43, 'rank': 427}, {'title': '就職・進学', 'score': 3.53, 'rank': 380}, {'title': 'アクセス・立地', 'score': 3.75, 'rank': 95}, {'title': '施設・設備', 'score': 3.55, 'rank': 305}, {'title': '友人・恋愛', 'score': 3.57, 'rank': 286}, {'title': '学生生活', 'score': 2.97, 'rank': 422}]
#     学べる学問：
#     ['法学', '経営学・商学', '歯学', '看護', '体育・健康科学']
#     学費：
#     [{'category': '法学部', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 685000, 'gakuhi_upper': 685000}, {'category': '経営学部', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 685000, 'gakuhi_upper': 685000}]
#     最寄り駅：穂積駅
#     学部：['法学部', '経営学部', '歯学部', '保健医療学部']
#     口コミ順位：286
#
# 麻布大学
#
#     大学名：麻布大学
#     偏差値：37.5 ～ 60.0
#     都道府県：神奈川県
#     形態：私立
#     評価：3.87
#     口コミ件数：137
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.64, 'rank': 276}, {'title': '研究室・ゼミ', 'score': 3.94, 'rank': 34}, {'title': '就職・進学', 'score': 3.55, 'rank': 362}, {'title': 'アクセス・立地', 'score': 3.31, 'rank': 188}, {'title': '施設・設備', 'score': 3.98, 'rank': 72}, {'title': '友人・恋愛', 'score': 3.71, 'rank': 158}, {'title': '学生生活', 'score': 3.53, 'rank': 133}]
#     学べる学問：
#     ['獣医学', '畜産学', '農芸化学', '検査技術', '食物・栄養学', '生物工学', '総合科学']
#     学費：
#     [{'category': '獣医学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 850000, 'gakuhi_upper': 1250000}, {'category': '生命・環境科学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 850000, 'gakuhi_upper': 850000}]
#     最寄り駅：矢部駅
#     学部：['獣医学部', '生命・環境科学部']
#     口コミ順位：151
#
# 足利大学
#
#     大学名：足利大学
#     偏差値：0 ～ 42.5
#     都道府県：栃木県
#     形態：私立
#     評価：3.23
#     口コミ件数：13
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.17, 'rank': 548}, {'title': '研究室・ゼミ', 'score': 3.38, 'rank': 451}, {'title': '就職・進学', 'score': 3.13, 'rank': 535}, {'title': 'アクセス・立地', 'score': 3.0, 'rank': 280}, {'title': '施設・設備', 'score': 2.9, 'rank': 535}, {'title': '友人・恋愛', 'score': 3.0, 'rank': 550}, {'title': '学生生活', 'score': 3.0, 'rank': 410}]
#     学べる学問：
#     ['機械工学', '情報工学', '電気・電子・通信工学', '建築・土木・環境工学', '看護']
#     学費：
#     [{'category': '工学部', 'enrollment_fee_lower': 270000, 'enrollment_fee_upper': 270000, 'gakuhi_lower': 1260000, 'gakuhi_upper': 1260000}, {'category': '看護学部', 'enrollment_fee_lower': 270000, 'enrollment_fee_upper': 270000, 'gakuhi_lower': 1460000, 'gakuhi_upper': 1460000}]
#     最寄り駅：山前駅
#     学部：['工学部', '看護学部']
#     口コミ順位：558
#
# 芦屋大学
#
#     大学名：芦屋大学
#     偏差値：0 ～ 0
#     都道府県：兵庫県
#     形態：私立
#     評価：3.58
#     口コミ件数：21
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.62, 'rank': 304}, {'title': '研究室・ゼミ', 'score': 3.63, 'rank': 269}, {'title': '就職・進学', 'score': 3.55, 'rank': 367}, {'title': 'アクセス・立地', 'score': 2.99, 'rank': 287}, {'title': '施設・設備', 'score': 2.87, 'rank': 539}, {'title': '友人・恋愛', 'score': 3.73, 'rank': 145}, {'title': '学生生活', 'score': 3.14, 'rank': 333}]
#     学べる学問：
#     ['国際関係学', '心理学', '体育・健康科学', '教育学', '教職（小学校）', '経営学・商学']
#     学費：
#     [{'category': '臨床教育学部', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 750000, 'gakuhi_upper': 750000}, {'category': '経営教育学部', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 750000, 'gakuhi_upper': 750000}]
#     最寄り駅：芦屋川駅
#     学部：['臨床教育学部', '経営教育学部']
#     口コミ順位：412
#
# 亜細亜大学
#
#     大学名：亜細亜大学
#     偏差値：40.0 ～ 50.0
#     都道府県：東京都
#     形態：私立
#     評価：3.68
#     口コミ件数：238
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.43, 'rank': 460}, {'title': '研究室・ゼミ', 'score': 3.56, 'rank': 336}, {'title': '就職・進学', 'score': 3.31, 'rank': 487}, {'title': 'アクセス・立地', 'score': 3.19, 'rank': 227}, {'title': '施設・設備', 'score': 3.61, 'rank': 260}, {'title': '友人・恋愛', 'score': 3.91, 'rank': 43}, {'title': '学生生活', 'score': 3.41, 'rank': 186}]
#     学べる学問：
#     ['法学', '経済学', '経営学・商学', '観光学', '国際関係学', '文化学', '英米語', '経営学・商学', '社会学']
#     学費：
#     [{'category': '法学部', 'enrollment_fee_lower': 230000, 'enrollment_fee_upper': 230000, 'gakuhi_lower': 670000, 'gakuhi_upper': 670000}, {'category': '経済学部', 'enrollment_fee_lower': 230000, 'enrollment_fee_upper': 230000, 'gakuhi_lower': 670000, 'gakuhi_upper': 670000}]
#     最寄り駅：東小金井駅
#     学部：['法学部', '経済学部', '経営学部', '国際関係学部', '都市創造学部']
#     口コミ順位：312
#
# 跡見学園女子大学
#
#     大学名：跡見学園女子大学
#     偏差値：35.0 ～ 45.0
#     都道府県：埼玉県
#     形態：私立
#     評価：3.77
#     口コミ件数：198
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.53, 'rank': 380}, {'title': '研究室・ゼミ', 'score': 3.48, 'rank': 395}, {'title': '就職・進学', 'score': 3.81, 'rank': 194}, {'title': 'アクセス・立地', 'score': 3.04, 'rank': 264}, {'title': '施設・設備', 'score': 3.49, 'rank': 336}, {'title': '友人・恋愛', 'score': 3.42, 'rank': 408}, {'title': '学生生活', 'score': 2.68, 'rank': 497}]
#     学べる学問：
#     ['西洋史', '文化学', '日本史', '日本文学', '芸術理論', '経営学・商学', '生活科学', '観光学', '社会学', '総合科学', '心理学']
#     学費：
#     [{'category': '文学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 742000, 'gakuhi_upper': 742000}, {'category': 'マネジメント学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 742000, 'gakuhi_upper': 742000}]
#     最寄り駅：新座駅
#     学部：['文学部', 'マネジメント学部', '観光コミュニティ学部', '心理学部']
#     口コミ順位：232
#
# 育英大学
#
#     大学名：育英大学
#     偏差値：0 ～ 0
#     都道府県：群馬県
#     形態：私立
#     評価：3.33
#     口コミ件数：2
#     口コミ（評判）：
#     []
#     学べる学問：
#     ['教育学']
#     学費：
#     []
#     最寄り駅：井野駅
#     学部：['教育学部']
#     口コミ順位：None
#
# 石川県立看護大学
#
#     大学名：石川県立看護大学
#     偏差値：0 ～ 0
#     都道府県：石川県
#     形態：公立
#     評価：4.19
#     口コミ件数：16
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 4.02, 'rank': 13}, {'title': '研究室・ゼミ', 'score': 3.17, 'rank': 82}, {'title': '就職・進学', 'score': 4.32, 'rank': 10}, {'title': 'アクセス・立地', 'score': 2.41, 'rank': 62}, {'title': '施設・設備', 'score': 3.84, 'rank': 18}, {'title': '友人・恋愛', 'score': 3.57, 'rank': 54}, {'title': '学生生活', 'score': 2.52, 'rank': 80}]
#     学べる学問：
#     ['看護']
#     学費：
#     [{'category': '地域内', 'enrollment_fee_lower': 282000, 'enrollment_fee_upper': 282000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}, {'category': '地域外', 'enrollment_fee_lower': 423000, 'enrollment_fee_upper': 423000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}]
#     最寄り駅：高松駅
#     学部：['看護学部']
#     口コミ順位：6
#
# 石川県立大学
#
#     大学名：石川県立大学
#     偏差値：47.5 ～ 50.0
#     都道府県：石川県
#     形態：公立
#     評価：3.72
#     口コミ件数：33
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.51, 'rank': 71}, {'title': '研究室・ゼミ', 'score': 3.64, 'rank': 53}, {'title': '就職・進学', 'score': 3.23, 'rank': 79}, {'title': 'アクセス・立地', 'score': 2.58, 'rank': 52}, {'title': '施設・設備', 'score': 3.62, 'rank': 33}, {'title': '友人・恋愛', 'score': 3.48, 'rank': 71}, {'title': '学生生活', 'score': 3.52, 'rank': 35}]
#     学べる学問：
#     ['農学', '畜産学', '農芸化学', '農業経済学・農業経営学', '農業工学・農業土木学']
#     学費：
#     [{'category': '地域内', 'enrollment_fee_lower': 282000, 'enrollment_fee_upper': 282000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}, {'category': '地域外', 'enrollment_fee_lower': 423000, 'enrollment_fee_upper': 423000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}]
#     最寄り駅：四十万駅
#     学部：['生物資源環境学部']
#     口コミ順位：65
#
# 石巻専修大学
#
#     大学名：石巻専修大学
#     偏差値：35.0 ～ 35.0
#     都道府県：宮城県
#     形態：私立
#     評価：3.61
#     口コミ件数：33
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.58, 'rank': 343}, {'title': '研究室・ゼミ', 'score': 3.68, 'rank': 224}, {'title': '就職・進学', 'score': 3.68, 'rank': 280}, {'title': 'アクセス・立地', 'score': 2.68, 'rank': 403}, {'title': '施設・設備', 'score': 3.52, 'rank': 325}, {'title': '友人・恋愛', 'score': 3.35, 'rank': 445}, {'title': '学生生活', 'score': 3.51, 'rank': 145}]
#     学べる学問：
#     ['経営学・商学', '観光学', '経営情報学', '機械工学', '情報工学', '電気・電子・通信工学', '農学', '生物工学', '文化学', '教職（小学校）', '教職（中学・高等学校）', '教職（幼稚園）', '教育学']
#     学費：
#     [{'category': '経営学部', 'enrollment_fee_lower': 230000, 'enrollment_fee_upper': 230000, 'gakuhi_lower': 673000, 'gakuhi_upper': 673000}, {'category': '理工学部', 'enrollment_fee_lower': 230000, 'enrollment_fee_upper': 230000, 'gakuhi_lower': 968000, 'gakuhi_upper': 968000}]
#     最寄り駅：曽波神駅
#     学部：['経営学部', '理工学部', '人間学部']
#     口コミ順位：391
#
# 一宮研伸大学
#
#     大学名：一宮研伸大学
#     偏差値：40.0 ～ 40.0
#     都道府県：愛知県
#     形態：私立
#     評価：0.0
#     口コミ件数：0
#     口コミ（評判）：
#     []
#     学べる学問：
#     ['看護']
#     学費：
#     [{'category': '看護学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 680000, 'gakuhi_upper': 680000}]
#     最寄り駅：尾張一宮駅
#     学部：['看護学部']
#     口コミ順位：None
#
# 茨城キリスト教大学
#
#     大学名：茨城キリスト教大学
#     偏差値：37.5 ～ 47.5
#     都道府県：茨城県
#     形態：私立
#     評価：3.72
#     口コミ件数：95
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.44, 'rank': 453}, {'title': '研究室・ゼミ', 'score': 3.61, 'rank': 287}, {'title': '就職・進学', 'score': 3.97, 'rank': 114}, {'title': 'アクセス・立地', 'score': 3.4, 'rank': 162}, {'title': '施設・設備', 'score': 3.71, 'rank': 199}, {'title': '友人・恋愛', 'score': 3.54, 'rank': 306}, {'title': '学生生活', 'score': 3.39, 'rank': 199}]
#     学べる学問：
#     ['英米語', '教職（小学校）', '児童学', '教職（幼稚園）', '教育学', '食物・栄養学', '社会福祉学', '心理学', '看護', '経営学・商学']
#     学費：
#     [{'category': '文学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 720000, 'gakuhi_upper': 720000}, {'category': '生活科学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 720000, 'gakuhi_upper': 720000}]
#     最寄り駅：大甕駅
#     学部：['文学部', '生活科学部', '看護学部', '経営学部']
#     口コミ順位：277
#
# 茨城県立医療大学
#
#     大学名：茨城県立医療大学
#     偏差値：0 ～ 0
#     都道府県：茨城県
#     形態：公立
#     評価：4.09
#     口コミ件数：43
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 4.13, 'rank': 4}, {'title': '研究室・ゼミ', 'score': 3.63, 'rank': 55}, {'title': '就職・進学', 'score': 4.52, 'rank': 2}, {'title': 'アクセス・立地', 'score': 2.35, 'rank': 65}, {'title': '施設・設備', 'score': 4.19, 'rank': 5}, {'title': '友人・恋愛', 'score': 4.11, 'rank': 2}, {'title': '学生生活', 'score': 3.57, 'rank': 31}]
#     学べる学問：
#     ['看護', '理学療法', '作業療法', '放射線技術']
#     学費：
#     [{'category': '地域内', 'enrollment_fee_lower': 282000, 'enrollment_fee_upper': 282000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}, {'category': '地域外', 'enrollment_fee_lower': 564000, 'enrollment_fee_upper': 564000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}]
#     最寄り駅：荒川沖駅
#     学部：['保健医療学部']
#     口コミ順位：15
#
# 茨城大学
#
#     大学名：茨城大学
#     偏差値：42.5 ～ 52.5
#     都道府県：茨城県
#     形態：国立
#     評価：3.73
#     口コミ件数：341
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.62, 'rank': 56}, {'title': '研究室・ゼミ', 'score': 3.72, 'rank': 54}, {'title': '就職・進学', 'score': 3.53, 'rank': 77}, {'title': 'アクセス・立地', 'score': 2.5, 'rank': 65}, {'title': '施設・設備', 'score': 3.33, 'rank': 64}, {'title': '友人・恋愛', 'score': 3.47, 'rank': 73}, {'title': '学生生活', 'score': 3.55, 'rank': 52}]
#     学べる学問：
#     ['社会学', 'マスコミ学', '法学', '経済学', '経営学・商学', '数学', '物理学', '化学', '生物学', '地球科学', '心理学', '教職（小学校）', '教職（中学・高等学校）', '教職（特別支援教育）', '教育学', '生物工学', '農芸化学', '農学', '機械工学', '材料工学', '電気・電子・通信工学', '情報工学', '建築・土木・環境工学']
#     学費：
#     []
#     最寄り駅：偕楽園駅
#     学部：['人文社会科学部', '理学部', '教育学部', '農学部', '工学部']
#     口コミ順位：74
#
# 日本医療創生大学
#
#     大学名：日本医療創生大学
#     偏差値：35.0 ～ 37.5
#     都道府県：福島県
#     形態：私立
#     評価：3.44
#     口コミ件数：44
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.44, 'rank': 457}, {'title': '研究室・ゼミ', 'score': 3.52, 'rank': 375}, {'title': '就職・進学', 'score': 3.19, 'rank': 526}, {'title': 'アクセス・立地', 'score': 2.9, 'rank': 324}, {'title': '施設・設備', 'score': 3.52, 'rank': 323}, {'title': '友人・恋愛', 'score': 3.35, 'rank': 444}, {'title': '学生生活', 'score': 3.38, 'rank': 209}]
#     学べる学問：
#     ['社会学', '英米語', '心理学', '薬学', '看護', '作業療法', '理学療法']
#     学費：
#     [{'category': '教養学部', 'enrollment_fee_lower': 100000, 'enrollment_fee_upper': 100000, 'gakuhi_lower': 750000, 'gakuhi_upper': 750000}, {'category': '薬学部', 'enrollment_fee_lower': 400000, 'enrollment_fee_upper': 400000, 'gakuhi_lower': 1300000, 'gakuhi_upper': 1300000}]
#     最寄り駅：いわき駅
#     学部：['教養学部', '薬学部', '【募集停止】科学技術部', '看護学部', '健康医療科学部']
#     口コミ順位：497
#
# 岩手医科大学
#
#     大学名：岩手医科大学
#     偏差値：35.0 ～ 65.0
#     都道府県：岩手県
#     形態：私立
#     評価：3.41
#     口コミ件数：56
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.26, 'rank': 527}, {'title': '研究室・ゼミ', 'score': 3.59, 'rank': 310}, {'title': '就職・進学', 'score': 3.37, 'rank': 473}, {'title': 'アクセス・立地', 'score': 2.71, 'rank': 391}, {'title': '施設・設備', 'score': 3.71, 'rank': 201}, {'title': '友人・恋愛', 'score': 3.68, 'rank': 185}, {'title': '学生生活', 'score': 3.1, 'rank': 356}]
#     学べる学問：
#     ['医学', '歯学', '薬学', '看護']
#     学費：
#     [{'category': '医学部', 'enrollment_fee_lower': 2000000, 'enrollment_fee_upper': 2000000, 'gakuhi_lower': 2500000, 'gakuhi_upper': 2500000}, {'category': '歯学部', 'enrollment_fee_lower': 600000, 'enrollment_fee_upper': 600000, 'gakuhi_lower': 2500000, 'gakuhi_upper': 2500000}]
#     最寄り駅：上盛岡駅
#     学部：['医学部', '歯学部', '薬学部', '看護学部']
#     口コミ順位：509
#
# 岩手県立大学
#
#     大学名：岩手県立大学
#     偏差値：45.0 ～ 45.0
#     都道府県：岩手県
#     形態：公立
#     評価：3.89
#     口コミ件数：116
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.72, 'rank': 45}, {'title': '研究室・ゼミ', 'score': 3.65, 'rank': 52}, {'title': '就職・進学', 'score': 3.96, 'rank': 37}, {'title': 'アクセス・立地', 'score': 2.34, 'rank': 66}, {'title': '施設・設備', 'score': 3.9, 'rank': 14}, {'title': '友人・恋愛', 'score': 3.72, 'rank': 25}, {'title': '学生生活', 'score': 3.68, 'rank': 19}]
#     学べる学問：
#     ['看護', '社会福祉学', '心理学', '情報工学', '政治学', '経営学・商学', '総合科学']
#     学費：
#     [{'category': '地域内', 'enrollment_fee_lower': 225600, 'enrollment_fee_upper': 225600, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}, {'category': '地域外', 'enrollment_fee_lower': 338400, 'enrollment_fee_upper': 338400, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}]
#     最寄り駅：雫石駅
#     学部：['看護学部', '社会福祉学部', 'ソフトウェア情報学部', '総合政策学部']
#     口コミ順位：40
#
# 岩手大学
#
#     大学名：岩手大学
#     偏差値：42.5 ～ 62.5
#     都道府県：岩手県
#     形態：国立
#     評価：3.81
#     口コミ件数：283
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.64, 'rank': 53}, {'title': '研究室・ゼミ', 'score': 3.73, 'rank': 52}, {'title': '就職・進学', 'score': 3.54, 'rank': 76}, {'title': 'アクセス・立地', 'score': 3.82, 'rank': 16}, {'title': '施設・設備', 'score': 3.36, 'rank': 62}, {'title': '友人・恋愛', 'score': 3.79, 'rank': 21}, {'title': '学生生活', 'score': 3.81, 'rank': 22}]
#     学べる学問：
#     ['農学', '農芸化学', '畜産学', '獣医学', '森林科学', '教職（小学校）', '教職（中学・高等学校）', '教職（特別支援教育）', '文化学', '政治学', '応用化学', '生物工学', '応用物理学', '材料工学', '機械工学']
#     学費：
#     []
#     最寄り駅：上盛岡駅
#     学部：['農学部', '教育学部', '人文社会科学部', '理工学部']
#     口コミ順位：56
#
# 岩手保健医療大学
#
#     大学名：岩手保健医療大学
#     偏差値：35.0 ～ 35.0
#     都道府県：岩手県
#     形態：私立
#     評価：3.67
#     口コミ件数：3
#     口コミ（評判）：
#     []
#     学べる学問：
#     ['看護']
#     学費：
#     [{'category': '看護学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 1000000, 'gakuhi_upper': 1000000}]
#     最寄り駅：盛岡駅
#     学部：['看護学部']
#     口コミ順位：None
#
# 植草学園大学
#
#     大学名：植草学園大学
#     偏差値：35.0 ～ 35.0
#     都道府県：千葉県
#     形態：私立
#     評価：3.8
#     口コミ件数：30
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.61, 'rank': 310}, {'title': '研究室・ゼミ', 'score': 3.63, 'rank': 268}, {'title': '就職・進学', 'score': 3.83, 'rank': 185}, {'title': 'アクセス・立地', 'score': 2.37, 'rank': 499}, {'title': '施設・設備', 'score': 3.8, 'rank': 148}, {'title': '友人・恋愛', 'score': 3.73, 'rank': 143}, {'title': '学生生活', 'score': 2.79, 'rank': 472}]
#     学べる学問：
#     ['教職（小学校）', '児童学', '教職（幼稚園）', '教職（特別支援教育）', '理学療法']
#     学費：
#     [{'category': '発達教育学部', 'enrollment_fee_lower': 270000, 'enrollment_fee_upper': 270000, 'gakuhi_lower': 780000, 'gakuhi_upper': 780000}, {'category': '保健医療学部', 'enrollment_fee_lower': 270000, 'enrollment_fee_upper': 270000, 'gakuhi_lower': 850000, 'gakuhi_upper': 850000}]
#     最寄り駅：千城台北駅
#     学部：['発達教育学部', '保健医療学部']
#     口コミ順位：212
#
# 上野学園大学
#
#     大学名：上野学園大学
#     偏差値：0 ～ 0
#     都道府県：東京都
#     形態：私立
#     評価：3.49
#     口コミ件数：23
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.58, 'rank': 345}, {'title': '研究室・ゼミ', 'score': 3.01, 'rank': 541}, {'title': '就職・進学', 'score': 3.01, 'rank': 551}, {'title': 'アクセス・立地', 'score': 3.69, 'rank': 105}, {'title': '施設・設備', 'score': 3.55, 'rank': 306}, {'title': '友人・恋愛', 'score': 3.64, 'rank': 225}, {'title': '学生生活', 'score': 2.85, 'rank': 460}]
#     学べる学問：
#     ['音楽', '教職（中学・高等学校）']
#     学費：
#     [{'category': '音楽学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 807000, 'gakuhi_upper': 1545000}]
#     最寄り駅：稲荷町駅
#     学部：['音楽学部']
#     口コミ順位：471
#
# 宇都宮共和大学
#
#     大学名：宇都宮共和大学
#     偏差値：0 ～ 0
#     都道府県：栃木県
#     形態：私立
#     評価：3.84
#     口コミ件数：13
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.63, 'rank': 292}, {'title': '研究室・ゼミ', 'score': 3.25, 'rank': 493}, {'title': '就職・進学', 'score': 3.81, 'rank': 197}, {'title': 'アクセス・立地', 'score': 3.48, 'rank': 144}, {'title': '施設・設備', 'score': 3.91, 'rank': 99}, {'title': '友人・恋愛', 'score': 3.32, 'rank': 459}, {'title': '学生生活', 'score': 3.17, 'rank': 322}]
#     学べる学問：
#     ['経済学', '社会学', '児童学', '教職（幼稚園）']
#     学費：
#     [{'category': 'シティライフ学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 650000, 'gakuhi_upper': 650000}, {'category': '子ども生活学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 650000, 'gakuhi_upper': 650000}]
#     最寄り駅：宇都宮駅
#     学部：['シティライフ学部', '子ども生活学部']
#     口コミ順位：175
#
# 宇都宮大学
#
#     大学名：宇都宮大学
#     偏差値：45.0 ～ 55.0
#     都道府県：栃木県
#     形態：国立
#     評価：3.82
#     口コミ件数：176
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.66, 'rank': 47}, {'title': '研究室・ゼミ', 'score': 3.83, 'rank': 28}, {'title': '就職・進学', 'score': 3.7, 'rank': 58}, {'title': 'アクセス・立地', 'score': 3.43, 'rank': 25}, {'title': '施設・設備', 'score': 3.55, 'rank': 33}, {'title': '友人・恋愛', 'score': 3.78, 'rank': 25}, {'title': '学生生活', 'score': 4.05, 'rank': 6}]
#     学べる学問：
#     ['文化学', '国際関係学', '英米語', '農学', '農業工学・農業土木学', '農業経済学・農業経営学', '森林科学', '農芸化学', '教職（小学校）', '教職（中学・高等学校）', '教職（特別支援教育）', '教育学', '機械工学', '情報工学', '電気・電子・通信工学', '応用化学', '政治学', '建築・土木・環境工学']
#     学費：
#     []
#     最寄り駅：宇都宮駅
#     学部：['国際学部', '農学部', '教育学部', '工学部', '地域デザイン科学部']
#     口コミ順位：55
#
# 宇部フロンティア大学
#
#     大学名：宇部フロンティア大学
#     偏差値：0 ～ 0
#     都道府県：山口県
#     形態：私立
#     評価：3.58
#     口コミ件数：11
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.53, 'rank': 389}, {'title': '研究室・ゼミ', 'score': 3.23, 'rank': 503}, {'title': '就職・進学', 'score': 4.07, 'rank': 79}, {'title': 'アクセス・立地', 'score': 2.36, 'rank': 500}, {'title': '施設・設備', 'score': 3.56, 'rank': 300}, {'title': '友人・恋愛', 'score': 3.27, 'rank': 484}, {'title': '学生生活', 'score': 3.4, 'rank': 195}]
#     学べる学問：
#     ['社会福祉学', '心理学', '看護']
#     学費：
#     [{'category': '人間社会学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 650000, 'gakuhi_upper': 650000}, {'category': '人間健康学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 970000, 'gakuhi_upper': 970000}]
#     最寄り駅：岩鼻駅
#     学部：['人間社会学部', '人間健康学部']
#     口コミ順位：416
#
# 浦和大学
#
#     大学名：浦和大学
#     偏差値：0 ～ 35.0
#     都道府県：埼玉県
#     形態：私立
#     評価：3.89
#     口コミ件数：18
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.72, 'rank': 192}, {'title': '研究室・ゼミ', 'score': 3.33, 'rank': 468}, {'title': '就職・進学', 'score': 3.7, 'rank': 272}, {'title': 'アクセス・立地', 'score': 3.23, 'rank': 216}, {'title': '施設・設備', 'score': 3.67, 'rank': 225}, {'title': '友人・恋愛', 'score': 3.61, 'rank': 256}, {'title': '学生生活', 'score': 3.82, 'rank': 47}]
#     学べる学問：
#     ['社会福祉学', '児童学', '教職（幼稚園）', '教職（小学校）']
#     学費：
#     [{'category': '総合福祉学部', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 700000, 'gakuhi_upper': 700000}, {'category': 'こども学部', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 700000, 'gakuhi_upper': 700000}]
#     最寄り駅：浦和美園駅
#     学部：['総合福祉学部', 'こども学部']
#     口コミ順位：136
#
# ＳＢＩ大学院大学
#
#     大学名：ＳＢＩ大学院大学
#     偏差値：0 ～ 0
#     都道府県：神奈川県
#     形態：私立
#     評価：0.0
#     口コミ件数：0
#     口コミ（評判）：
#     []
#     学べる学問：
#     ['経営学・商学']
#     学費：
#     [{'category': '経営管理研究科', 'enrollment_fee_lower': 100000, 'enrollment_fee_upper': 100000, 'gakuhi_lower': 1200000, 'gakuhi_upper': 1200000}]
#     最寄り駅：関内駅
#     学部：['経営管理研究科']
#     口コミ順位：None
#
# 江戸川大学
#
#     大学名：江戸川大学
#     偏差値：0 ～ 37.5
#     都道府県：千葉県
#     形態：私立
#     評価：3.49
#     口コミ件数：50
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.63, 'rank': 287}, {'title': '研究室・ゼミ', 'score': 3.9, 'rank': 52}, {'title': '就職・進学', 'score': 3.21, 'rank': 519}, {'title': 'アクセス・立地', 'score': 3.07, 'rank': 256}, {'title': '施設・設備', 'score': 3.24, 'rank': 451}, {'title': '友人・恋愛', 'score': 3.46, 'rank': 382}, {'title': '学生生活', 'score': 3.05, 'rank': 384}]
#     学べる学問：
#     ['心理学', '文化学', '社会学', '観光学', '総合科学', 'マスコミ学', '映像', '放送', 'その他芸術', '英米語']
#     学費：
#     [{'category': '社会学部', 'enrollment_fee_lower': 320000, 'enrollment_fee_upper': 320000, 'gakuhi_lower': 680000, 'gakuhi_upper': 680000}, {'category': 'メディアコミュニケーション学部', 'enrollment_fee_lower': 320000, 'enrollment_fee_upper': 320000, 'gakuhi_lower': 680000, 'gakuhi_upper': 680000}]
#     最寄り駅：豊四季駅
#     学部：['社会学部', 'メディアコミュニケーション学部']
#     口コミ順位：469
#
# 愛媛県立医療技術大学
#
#     大学名：愛媛県立医療技術大学
#     偏差値：0 ～ 0
#     都道府県：愛媛県
#     形態：公立
#     評価：4.16
#     口コミ件数：27
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 4.23, 'rank': 3}, {'title': '研究室・ゼミ', 'score': 3.49, 'rank': 68}, {'title': '就職・進学', 'score': 4.5, 'rank': 4}, {'title': 'アクセス・立地', 'score': 2.65, 'rank': 46}, {'title': '施設・設備', 'score': 3.58, 'rank': 38}, {'title': '友人・恋愛', 'score': 3.51, 'rank': 65}, {'title': '学生生活', 'score': 2.68, 'rank': 77}]
#     学べる学問：
#     ['看護', '検査技術']
#     学費：
#     [{'category': '地域内', 'enrollment_fee_lower': 282000, 'enrollment_fee_upper': 282000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}, {'category': '地域外', 'enrollment_fee_lower': 423000, 'enrollment_fee_upper': 423000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}]
#     最寄り駅：久米駅
#     学部：['保健科学部']
#     口コミ順位：7
#
# 愛媛大学
#
#     大学名：愛媛大学
#     偏差値：45.0 ～ 65.0
#     都道府県：愛媛県
#     形態：国立
#     評価：3.84
#     口コミ件数：432
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.6, 'rank': 61}, {'title': '研究室・ゼミ', 'score': 3.79, 'rank': 38}, {'title': '就職・進学', 'score': 3.63, 'rank': 67}, {'title': 'アクセス・立地', 'score': 4.12, 'rank': 8}, {'title': '施設・設備', 'score': 3.67, 'rank': 22}, {'title': '友人・恋愛', 'score': 3.77, 'rank': 26}, {'title': '学生生活', 'score': 3.84, 'rank': 19}]
#     学べる学問：
#     ['地理学', '西洋史', '哲学・倫理・宗教', '文化学', '日本史', '数学', '物理学', '化学', '生物学', '地球科学', '機械工学', '情報工学', '電気・電子・通信工学', '建築・土木・環境工学', '応用化学', '農業経済学・農業経営学', '農芸化学', '農学', '教職（小学校）', '教職（中学・高等学校）', '教職（幼稚園）', '教職（特別支援教育）', '医学', '看護', '経済学', '経営学・商学', '機械工学', '水産学', '建築・土木・環境工学']
#     学費：
#     []
#     最寄り駅：赤十字病院前駅
#     学部：['法文学部', '理学部', '工学部', '農学部', '教育学部', '医学部', '社会共創学部', 'スーパーサイエンス特別コース']
#     口コミ順位：52
#
# エリザベト音楽大学
#
#     大学名：エリザベト音楽大学
#     偏差値：0 ～ 37.5
#     都道府県：広島県
#     形態：私立
#     評価：3.65
#     口コミ件数：19
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.95, 'rank': 48}, {'title': '研究室・ゼミ', 'score': 3.65, 'rank': 257}, {'title': '就職・進学', 'score': 3.2, 'rank': 522}, {'title': 'アクセス・立地', 'score': 4.8, 'rank': 1}, {'title': '施設・設備', 'score': 3.69, 'rank': 213}, {'title': '友人・恋愛', 'score': 3.71, 'rank': 165}, {'title': '学生生活', 'score': 3.45, 'rank': 169}]
#     学べる学問：
#     ['文化学', '音楽', '教職（幼稚園）']
#     学費：
#     [{'category': '音楽学部', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 850000, 'gakuhi_upper': 1300000}]
#     最寄り駅：銀山町駅
#     学部：['音楽学部']
#     口コミ順位：349
#
# 奥羽大学
#
#     大学名：奥羽大学
#     偏差値：37.5 ～ 37.5
#     都道府県：福島県
#     形態：私立
#     評価：3.44
#     口コミ件数：25
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.24, 'rank': 532}, {'title': '研究室・ゼミ', 'score': 3.3, 'rank': 479}, {'title': '就職・進学', 'score': 3.25, 'rank': 509}, {'title': 'アクセス・立地', 'score': 2.87, 'rank': 340}, {'title': '施設・設備', 'score': 3.1, 'rank': 497}, {'title': '友人・恋愛', 'score': 3.39, 'rank': 425}, {'title': '学生生活', 'score': 2.56, 'rank': 521}]
#     学べる学問：
#     ['歯学', '薬学']
#     学費：
#     [{'category': '歯学部', 'enrollment_fee_lower': 500000, 'enrollment_fee_upper': 500000, 'gakuhi_lower': 3500000, 'gakuhi_upper': 3500000}, {'category': '薬学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 1500000, 'gakuhi_upper': 1500000}]
#     最寄り駅：郡山富田駅
#     学部：['歯学部', '薬学部']
#     口コミ順位：499
#
# 桜花学園大学
#
#     大学名：桜花学園大学
#     偏差値：35.0 ～ 42.5
#     都道府県：愛知県
#     形態：私立
#     評価：4.26
#     口コミ件数：55
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.97, 'rank': 42}, {'title': '研究室・ゼミ', 'score': 3.83, 'rank': 85}, {'title': '就職・進学', 'score': 4.52, 'rank': 7}, {'title': 'アクセス・立地', 'score': 2.59, 'rank': 435}, {'title': '施設・設備', 'score': 3.21, 'rank': 462}, {'title': '友人・恋愛', 'score': 3.96, 'rank': 28}, {'title': '学生生活', 'score': 3.86, 'rank': 39}]
#     学べる学問：
#     ['教職（小学校）', '児童学', '教職（幼稚園）', '国際関係学', '英米語', '英米語']
#     学費：
#     [{'category': '保育学部', 'enrollment_fee_lower': 240000, 'enrollment_fee_upper': 240000, 'gakuhi_lower': 685000, 'gakuhi_upper': 685000}, {'category': '学芸学部', 'enrollment_fee_lower': 240000, 'enrollment_fee_upper': 240000, 'gakuhi_lower': 685000, 'gakuhi_upper': 685000}]
#     最寄り駅：中京競馬場前駅
#     学部：['保育学部', '学芸学部']
#     口コミ順位：15
#
# 追手門学院大学
#
#     大学名：追手門学院大学
#     偏差値：42.5 ～ 50.0
#     都道府県：大阪府
#     形態：私立
#     評価：3.51
#     口コミ件数：214
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.43, 'rank': 461}, {'title': '研究室・ゼミ', 'score': 3.52, 'rank': 372}, {'title': '就職・進学', 'score': 3.45, 'rank': 434}, {'title': 'アクセス・立地', 'score': 2.44, 'rank': 475}, {'title': '施設・設備', 'score': 3.64, 'rank': 243}, {'title': '友人・恋愛', 'score': 3.62, 'rank': 242}, {'title': '学生生活', 'score': 3.13, 'rank': 337}]
#     学べる学問：
#     ['経済学', '法学', '経営学・商学', '心理学', '教育学', '社会学', '文化学', '中国語', '日本語', '英米語', '文化学', '政治学', '経済学', '経営学・商学', '観光学']
#     学費：
#     [{'category': '文系', 'enrollment_fee_lower': 260000, 'enrollment_fee_upper': 260000, 'gakuhi_lower': 750000, 'gakuhi_upper': 750000}]
#     最寄り駅：茨木駅
#     学部：['経済学部', '経営学部', '心理学部', '社会学部', '国際教養学部', '地域創造学部']
#     口コミ順位：454
#
# 桜美林大学
#
#     大学名：桜美林大学
#     偏差値：37.5 ～ 47.5
#     都道府県：東京都
#     形態：私立
#     評価：3.74
#     口コミ件数：295
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.68, 'rank': 234}, {'title': '研究室・ゼミ', 'score': 3.45, 'rank': 416}, {'title': '就職・進学', 'score': 3.49, 'rank': 413}, {'title': 'アクセス・立地', 'score': 2.95, 'rank': 300}, {'title': '施設・設備', 'score': 3.64, 'rank': 242}, {'title': '友人・恋愛', 'score': 3.69, 'rank': 174}, {'title': '学生生活', 'score': 3.51, 'rank': 142}]
#     学べる学問：
#     ['演劇', '音楽', '美術・デザイン', '映像', '体育・健康科学', '社会福祉学', '児童学', '経済学', '経営学・商学', '観光学', '航空・宇宙工学', '西洋史', '哲学・倫理・宗教', '文化学', '日本史', '英米語', '国際関係学', '英米語', '中国語', '日本語']
#     学費：
# ...
#     学べる学問：
#     ['獣医学', '農学', '畜産学', '農業経済学・農業経営学', '食物・栄養学', '農芸化学']
#     学費：
#     [{'category': '獣医学群', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 940000, 'gakuhi_upper': 940000}, {'category': '農食環境学群', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 940000, 'gakuhi_upper': 940000}]
#     最寄り駅：大麻駅
#     学部：['獣医学群', '農食環境学群']
#     口コミ順位：223
#
# 立教大学
#
#     大学名：立教大学
#     偏差値：55.0 ～ 65.0
#     都道府県：東京都
#     形態：私立
#     評価：4.01
#     口コミ件数：1115
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.8, 'rank': 117}, {'title': '研究室・ゼミ', 'score': 3.69, 'rank': 207}, {'title': '就職・進学', 'score': 3.7, 'rank': 266}, {'title': 'アクセス・立地', 'score': 3.84, 'rank': 84}, {'title': '施設・設備', 'score': 4.22, 'rank': 19}, {'title': '友人・恋愛', 'score': 3.91, 'rank': 42}, {'title': '学生生活', 'score': 3.9, 'rank': 34}]
#     学べる学問：
#     ['法学', '国際関係学', '政治学', '経済学', '国際関係学', '経営学・商学', '政治学', '哲学・倫理・宗教', '西洋史', '文化学', '日本史', '東洋史', '数学', '物理学', '化学', '生物学', '社会学', '英米語', '文化学', 'マスコミ学', '経営学・商学', '国際関係学', '英米語', '文化学', '英米語', '中国語', '日本語', 'フランス語', '経営学・商学', '観光学', '国際関係学', '社会福祉学', '社会学', '体育・健康科学', '心理学', '人間科学', '映像']
#     学費：
#     [{'category': '文系', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 785000, 'gakuhi_upper': 829000}, {'category': '理系', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 1085000, 'gakuhi_upper': 1085000}]
#     最寄り駅：池袋駅
#     学部：['法学部', '経済学部', '文学部', '理学部', '社会学部', '経営学部', '異文化コミュニケーション学部', '観光学部', 'コミュニティ福祉学部', '現代心理学部']
#     口コミ順位：66
#
# 立正大学
#
#     大学名：立正大学
#     偏差値：35.0 ～ 52.5
#     都道府県：東京都
#     形態：私立
#     評価：3.74
#     口コミ件数：383
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.68, 'rank': 233}, {'title': '研究室・ゼミ', 'score': 3.74, 'rank': 154}, {'title': '就職・進学', 'score': 3.37, 'rank': 470}, {'title': 'アクセス・立地', 'score': 3.86, 'rank': 79}, {'title': '施設・設備', 'score': 3.56, 'rank': 296}, {'title': '友人・恋愛', 'score': 3.52, 'rank': 323}, {'title': '学生生活', 'score': 3.34, 'rank': 228}]
#     学べる学問：
#     ['経済学', '経営学・商学', '哲学・倫理・宗教', '西洋史', '考古学・文化財学', '日本史', '東洋史', '哲学・倫理・宗教', '心理学', '社会福祉学', '教職（小学校）', '児童学', '教職（幼稚園）', '地球科学', '総合科学', '地理学', '法学']
#     学費：
#     [{'category': '文系', 'enrollment_fee_lower': 283000, 'enrollment_fee_upper': 283000, 'gakuhi_lower': 706000, 'gakuhi_upper': 706000}, {'category': '理系', 'enrollment_fee_lower': 283000, 'enrollment_fee_upper': 283000, 'gakuhi_lower': 706000, 'gakuhi_upper': 706000}]
#     最寄り駅：大崎広小路駅
#     学部：['経済学部', '経営学部', '文学部', '仏教学部', '心理学部', '社会福祉学部', '地球環境科学部', '法学部']
#     口コミ順位：255
#
# 立命館アジア太平洋大学
#
#     大学名：立命館アジア太平洋大学
#     偏差値：50.0 ～ 52.5
#     都道府県：大分県
#     形態：私立
#     評価：3.84
#     口コミ件数：120
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.58, 'rank': 341}, {'title': '研究室・ゼミ', 'score': 3.44, 'rank': 423}, {'title': '就職・進学', 'score': 4.05, 'rank': 82}, {'title': 'アクセス・立地', 'score': 1.99, 'rank': 554}, {'title': '施設・設備', 'score': 3.55, 'rank': 303}, {'title': '友人・恋愛', 'score': 4.04, 'rank': 15}, {'title': '学生生活', 'score': 4.0, 'rank': 16}]
#     学べる学問：
#     ['社会学', '観光学', '国際関係学', '総合科学', '経営学・商学', '国際関係学']
#     学費：
#     [{'category': 'アジア太平洋学部', 'enrollment_fee_lower': 130000, 'enrollment_fee_upper': 130000, 'gakuhi_lower': 1328000, 'gakuhi_upper': 1328000}, {'category': '国際経営学部', 'enrollment_fee_lower': 130000, 'enrollment_fee_upper': 130000, 'gakuhi_lower': 1328000, 'gakuhi_upper': 1328000}]
#     最寄り駅：亀川駅
#     学部：['アジア太平洋学部', '国際経営学部']
#     口コミ順位：171
#
# 立命館大学
#
#     大学名：立命館大学
#     偏差値：52.5 ～ 62.5
#     都道府県：京都府
#     形態：私立
#     評価：3.83
#     口コミ件数：1537
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.61, 'rank': 305}, {'title': '研究室・ゼミ', 'score': 3.75, 'rank': 143}, {'title': '就職・進学', 'score': 3.82, 'rank': 186}, {'title': 'アクセス・立地', 'score': 2.71, 'rank': 389}, {'title': '施設・設備', 'score': 3.81, 'rank': 145}, {'title': '友人・恋愛', 'score': 3.71, 'rank': 152}, {'title': '学生生活', 'score': 3.7, 'rank': 76}]
#     学べる学問：
#     ['法学', '政治学', '国際関係学', '経済学', '英米語', '中国語', '経営学・商学', '国際関係学', '地理学', '西洋史', '考古学・文化財学', '哲学・倫理・宗教', '文化学', '国際関係学', '英米語', '社会学', 'マスコミ学', '社会福祉学', '教職（小学校）', '児童学', '政治学', '総合科学', '映像', '数学', '情報科学', '物理学', '電気・電子・通信工学', '情報工学', '薬学', '応用化学', '生物工学', '情報科学', '英米語', '数学', '情報工学', '電気・電子・通信工学', '経営学・商学', '体育・健康科学', '心理学', '農業経済学・農業経営学', '文化学', '国際関係学', '英米語']
#     学費：
#     [{'category': '文系', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 798400, 'gakuhi_upper': 1086400}, {'category': '理系', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 1328600, 'gakuhi_upper': 1415000}]
#     最寄り駅：円町駅
#     学部：['法学部', '経済学部', '経営学部', '文学部', '国際関係学部', '産業社会学部', '政策科学部', '映像学部', '理工学部', '薬学部', '生命科学部', '情報理工学部', 'スポーツ健康科学部', '総合心理学部', '食マネジメント学部', 'グローバル教養学部']
#     口コミ順位：178
#
# 琉球大学
#
#     大学名：琉球大学
#     偏差値：40.0 ～ 65.0
#     都道府県：沖縄県
#     形態：国立
#     評価：3.79
#     口コミ件数：311
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.61, 'rank': 58}, {'title': '研究室・ゼミ', 'score': 3.62, 'rank': 72}, {'title': '就職・進学', 'score': 3.4, 'rank': 82}, {'title': 'アクセス・立地', 'score': 3.16, 'rank': 35}, {'title': '施設・設備', 'score': 3.39, 'rank': 55}, {'title': '友人・恋愛', 'score': 3.77, 'rank': 29}, {'title': '学生生活', 'score': 3.62, 'rank': 46}]
#     学べる学問：
#     ['法学', '政治学', '経済学', '国際関係学', '地理学', '数学', '物理学', '地球科学', '化学', '生物学', '原子力・エネルギー工学', '機械工学', '情報工学', '電気・電子・通信工学', '建築・土木・環境工学', '農学', '森林科学', '畜産学', '体育・健康科学', '農業経済学・農業経営学', '教職（小学校）', '教職（中学・高等学校）', '教職（特別支援教育）', '観光学', '経営学・商学', '医学', '看護', '検査技術']
#     学費：
#     []
#     最寄り駅：首里駅
#     学部：['人文社会学部', '理学部', '工学部', '農学部', '教育学部', '国際地域創造学部', '医学部']
#     口コミ順位：61
#
# 龍谷大学
#
#     大学名：龍谷大学
#     偏差値：42.5 ～ 52.5
#     都道府県：京都府
#     形態：私立
#     評価：3.8
#     口コミ件数：787
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.59, 'rank': 321}, {'title': '研究室・ゼミ', 'score': 3.7, 'rank': 196}, {'title': '就職・進学', 'score': 3.53, 'rank': 375}, {'title': 'アクセス・立地', 'score': 3.33, 'rank': 184}, {'title': '施設・設備', 'score': 3.77, 'rank': 158}, {'title': '友人・恋愛', 'score': 3.66, 'rank': 199}, {'title': '学生生活', 'score': 3.59, 'rank': 100}]
#     学べる学問：
#     ['法学', '政治学', '国際関係学', '英米語', '体育・健康科学', '経済学', '国際関係学', '経営学・商学', '国際関係学', '英米語', '体育・健康科学', '総合科学', '哲学・倫理・宗教', '文化学', '心理学', '教育学', '考古学・文化財学', '数学', '情報科学', '情報工学', '電気・電子・通信工学', '機械工学', '社会学', 'マスコミ学', '社会福祉学', '文化学', '国際関係学', '英米語', '政治学', '国際関係学', '英米語', '体育・健康科学', '総合科学', '農芸化学', '農学', '食物・栄養学', '農業経済学・農業経営学']
#     学費：
#     [{'category': '文系', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 761000, 'gakuhi_upper': 931000}, {'category': '理系', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 949000, 'gakuhi_upper': 979000}]
#     最寄り駅：深草駅
#     学部：['法学部', '経済学部', '経営学部', '文学部', '理工学部', '社会学部', '国際学部', '政策学部', '農学部']
#     口コミ順位：208
#
# 流通科学大学
#
#     大学名：流通科学大学
#     偏差値：37.5 ～ 40.0
#     都道府県：兵庫県
#     形態：私立
#     評価：3.7
#     口コミ件数：53
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.59, 'rank': 331}, {'title': '研究室・ゼミ', 'score': 3.87, 'rank': 66}, {'title': '就職・進学', 'score': 3.99, 'rank': 108}, {'title': 'アクセス・立地', 'score': 3.8, 'rank': 90}, {'title': '施設・設備', 'score': 3.95, 'rank': 85}, {'title': '友人・恋愛', 'score': 3.59, 'rank': 274}, {'title': '学生生活', 'score': 3.42, 'rank': 185}]
#     学べる学問：
#     ['経営学・商学', '経済学', '経営情報学', '経営学・商学', '観光学', '体育・健康科学', '社会学', '心理学']
#     学費：
#     [{'category': '商学部', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 770000, 'gakuhi_upper': 770000}, {'category': '経済学部', 'enrollment_fee_lower': 300000, 'enrollment_fee_upper': 300000, 'gakuhi_lower': 770000, 'gakuhi_upper': 770000}]
#     最寄り駅：学園都市駅
#     学部：['商学部', '【募集停止】サービス産業学部', '総合政策学部', '経済学部', '人間社会学部']
#     口コミ順位：295
#
# 流通経済大学
#
#     大学名：流通経済大学
#     偏差値：35.0 ～ 40.0
#     都道府県：茨城県
#     形態：私立
#     評価：3.6
#     口コミ件数：98
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.43, 'rank': 463}, {'title': '研究室・ゼミ', 'score': 3.62, 'rank': 277}, {'title': '就職・進学', 'score': 3.82, 'rank': 189}, {'title': 'アクセス・立地', 'score': 3.39, 'rank': 168}, {'title': '施設・設備', 'score': 3.57, 'rank': 289}, {'title': '友人・恋愛', 'score': 3.34, 'rank': 448}, {'title': '学生生活', 'score': 2.96, 'rank': 424}]
#     学べる学問：
#     ['経済学', '経営学・商学', '社会学', '観光学', '経営情報学', '法学', '政治学', '体育・健康科学']
#     学費：
#     [{'category': '経済学部', 'enrollment_fee_lower': 303400, 'enrollment_fee_upper': 303400, 'gakuhi_lower': 773000, 'gakuhi_upper': 773000}, {'category': '社会学部', 'enrollment_fee_lower': 303400, 'enrollment_fee_upper': 303400, 'gakuhi_lower': 773000, 'gakuhi_upper': 773000}]
#     最寄り駅：竜ヶ崎駅
#     学部：['経済学部', '社会学部', '流通情報学部', '法学部', 'スポーツ健康科学部']
#     口コミ順位：393
#
# 了徳寺大学
#
#     大学名：了徳寺大学
#     偏差値：35.0 ～ 37.5
#     都道府県：千葉県
#     形態：私立
#     評価：3.55
#     口コミ件数：29
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.43, 'rank': 468}, {'title': '研究室・ゼミ', 'score': 2.53, 'rank': 566}, {'title': '就職・進学', 'score': 3.51, 'rank': 395}, {'title': 'アクセス・立地', 'score': 3.38, 'rank': 172}, {'title': '施設・設備', 'score': 2.93, 'rank': 526}, {'title': '友人・恋愛', 'score': 3.79, 'rank': 88}, {'title': '学生生活', 'score': 2.9, 'rank': 442}]
#     学べる学問：
#     ['理学療法', '医療技術', '体育・健康科学', '看護']
#     学費：
#     [{'category': '健康科学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 800000, 'gakuhi_upper': 800000}]
#     最寄り駅：新浦安駅
#     学部：['健康科学部']
#     口コミ順位：428
#
# ルーテル学院大学
#
#     大学名：ルーテル学院大学
#     偏差値：0 ～ 0
#     都道府県：東京都
#     形態：私立
#     評価：3.67
#     口コミ件数：21
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.69, 'rank': 228}, {'title': '研究室・ゼミ', 'score': 3.62, 'rank': 281}, {'title': '就職・進学', 'score': 3.77, 'rank': 216}, {'title': 'アクセス・立地', 'score': 3.44, 'rank': 154}, {'title': '施設・設備', 'score': 3.11, 'rank': 493}, {'title': '友人・恋愛', 'score': 3.36, 'rank': 439}, {'title': '学生生活', 'score': 2.69, 'rank': 496}]
#     学べる学問：
#     ['社会福祉学', '児童学', '心理学', '哲学・倫理・宗教']
#     学費：
#     [{'category': '総合人間学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 800000, 'gakuhi_upper': 800000}]
#     最寄り駅：新小金井駅
#     学部：['総合人間学部']
#     口コミ順位：328
#
# 麗澤大学
#
#     大学名：麗澤大学
#     偏差値：35.0 ～ 47.5
#     都道府県：千葉県
#     形態：私立
#     評価：3.74
#     口コミ件数：59
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.45, 'rank': 449}, {'title': '研究室・ゼミ', 'score': 3.52, 'rank': 373}, {'title': '就職・進学', 'score': 3.44, 'rank': 439}, {'title': 'アクセス・立地', 'score': 2.88, 'rank': 333}, {'title': '施設・設備', 'score': 3.61, 'rank': 265}, {'title': '友人・恋愛', 'score': 3.75, 'rank': 124}, {'title': '学生生活', 'score': 3.59, 'rank': 102}]
#     学べる学問：
#     ['文化学', '国際関係学', '英米語', '中国語', '日本語', '経済学', '経営学・商学', '英米語']
#     学費：
#     [{'category': '外国語学部', 'enrollment_fee_lower': 260000, 'enrollment_fee_upper': 260000, 'gakuhi_lower': 830000, 'gakuhi_upper': 830000}, {'category': '経済学部', 'enrollment_fee_lower': 260000, 'enrollment_fee_upper': 260000, 'gakuhi_lower': 830000, 'gakuhi_upper': 830000}]
#     最寄り駅：南柏駅
#     学部：['外国語学部', '経済学部']
#     口コミ順位：262
#
# 和歌山県立医科大学
#
#     大学名：和歌山県立医科大学
#     偏差値：65.0 ～ 65.0
#     都道府県：和歌山県
#     形態：公立
#     評価：3.76
#     口コミ件数：40
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.64, 'rank': 55}, {'title': '研究室・ゼミ', 'score': 3.58, 'rank': 62}, {'title': '就職・進学', 'score': 4.18, 'rank': 17}, {'title': 'アクセス・立地', 'score': 2.61, 'rank': 49}, {'title': '施設・設備', 'score': 3.48, 'rank': 51}, {'title': '友人・恋愛', 'score': 3.69, 'rank': 34}, {'title': '学生生活', 'score': 3.0, 'rank': 68}]
#     学べる学問：
#     ['医学', '看護', '保健']
#     学費：
#     [{'category': '地域内', 'enrollment_fee_lower': 282000, 'enrollment_fee_upper': 282000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}, {'category': '地域外', 'enrollment_fee_lower': 423000, 'enrollment_fee_upper': 752000, 'gakuhi_lower': 535800, 'gakuhi_upper': 535800}]
#     最寄り駅：紀三井寺駅
#     学部：['医学部', '保健看護学部']
#     口コミ順位：62
#
# 和歌山信愛大学
#
#     大学名：和歌山信愛大学
#     偏差値：0 ～ 0
#     都道府県：和歌山県
#     形態：私立
#     評価：0.0
#     口コミ件数：0
#     口コミ（評判）：
#     []
#     学べる学問：
#     ['教職（小学校）']
#     学費：
#     []
#     最寄り駅：
#     学部：['教育学部']
#     口コミ順位：None
#
# 和歌山大学
#
#     大学名：和歌山大学
#     偏差値：47.5 ～ 52.5
#     都道府県：和歌山県
#     形態：国立
#     評価：3.81
#     口コミ件数：220
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.64, 'rank': 54}, {'title': '研究室・ゼミ', 'score': 3.75, 'rank': 50}, {'title': '就職・進学', 'score': 3.75, 'rank': 49}, {'title': 'アクセス・立地', 'score': 2.57, 'rank': 62}, {'title': '施設・設備', 'score': 3.18, 'rank': 73}, {'title': '友人・恋愛', 'score': 3.73, 'rank': 40}, {'title': '学生生活', 'score': 3.76, 'rank': 23}]
#     学べる学問：
#     ['法学', '経済学', '経営学・商学', '心理学', '教職（小学校）', '教職（中学・高等学校）', '教職（特別支援教育）', '教育学', '機械工学', '情報工学', '電気・電子・通信工学', '建築・土木・環境工学', '応用物理学', '文化学', '経営学・商学', '観光学']
#     学費：
#     []
#     最寄り駅：和歌山大学前駅
#     学部：['経済学部', '教育学部', 'システム工学部', '観光学部']
#     口コミ順位：57
#
# 和光大学
#
#     大学名：和光大学
#     偏差値：0 ～ 37.5
#     都道府県：東京都
#     形態：私立
#     評価：3.62
#     口コミ件数：78
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.57, 'rank': 349}, {'title': '研究室・ゼミ', 'score': 3.67, 'rank': 231}, {'title': '就職・進学', 'score': 2.99, 'rank': 554}, {'title': 'アクセス・立地', 'score': 2.67, 'rank': 406}, {'title': '施設・設備', 'score': 3.35, 'rank': 405}, {'title': '友人・恋愛', 'score': 3.49, 'rank': 359}, {'title': '学生生活', 'score': 3.32, 'rank': 237}]
#     学べる学問：
#     ['美術・デザイン', '文化学', '心理学', '教職（小学校）', '児童学', '教職（幼稚園）', '社会学', '経済学', '経営学・商学']
#     学費：
#     [{'category': '表現学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 850000, 'gakuhi_upper': 850000}, {'category': '現代人間学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 850000, 'gakuhi_upper': 850000}]
#     最寄り駅：鶴川駅
#     学部：['表現学部', '現代人間学部', '経済経営学部']
#     口コミ順位：373
#
# 早稲田大学
#
#     大学名：早稲田大学
#     偏差値：62.5 ～ 70.0
#     都道府県：東京都
#     形態：私立
#     評価：4.03
#     口コミ件数：2551
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.78, 'rank': 137}, {'title': '研究室・ゼミ', 'score': 3.8, 'rank': 99}, {'title': '就職・進学', 'score': 3.81, 'rank': 193}, {'title': 'アクセス・立地', 'score': 3.89, 'rank': 73}, {'title': '施設・設備', 'score': 3.88, 'rank': 108}, {'title': '友人・恋愛', 'score': 3.8, 'rank': 79}, {'title': '学生生活', 'score': 4.25, 'rank': 7}]
#     学べる学問：
#     ['政治学', '経済学', '国際関係学', '心理学', '教職（小学校）', '教育学', '日本文学', '教職（中学・高等学校）', '総合科学', '国際関係学', '英米語', '総合科学', '西洋史', '考古学・文化財学', '哲学・倫理・宗教', '日本史', '社会学', '文化学', '社会学', '英米語', '人間科学', 'その他芸術', '数学', '情報工学', '機械工学', '航空・宇宙工学', '電気・電子・通信工学', '建築・土木・環境工学', '機械工学', '経営工学', '材料工学', '物理学', '応用物理学', '化学', '応用化学', '医療技術', '総合科学', '社会福祉学', '保健', '総合情報学', '体育・健康科学']
#     学費：
#     [{'category': '文系', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 960000, 'gakuhi_upper': 1446000}, {'category': '理系', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 971000, 'gakuhi_upper': 1446000}]
#     最寄り駅：早稲田駅
#     学部：['法学部', '政治経済学部', '商学部', '教育学部', '社会科学部', '国際教養学部', '文学部', '文化構想学部', '基幹理工学部', '創造理工学部', '先進理工学部', '人間科学部', 'スポーツ科学部']
#     口コミ順位：59
#
# 稚内北星学園大学
#
#     大学名：稚内北星学園大学
#     偏差値：0 ～ 0
#     都道府県：北海道
#     形態：私立
#     評価：4.25
#     口コミ件数：4
#     口コミ（評判）：
#     []
#     学べる学問：
#     ['観光学', '教職（中学・高等学校）', '総合科学', '総合情報学', '情報科学']
#     学費：
#     [{'category': '情報メディア学部', 'enrollment_fee_lower': 200000, 'enrollment_fee_upper': 200000, 'gakuhi_lower': 700000, 'gakuhi_upper': 700000}]
#     最寄り駅：南稚内駅
#     学部：['情報メディア学部']
#     口コミ順位：None
#
# 和洋女子大学
#
#     大学名：和洋女子大学
#     偏差値：0 ～ 42.5
#     都道府県：千葉県
#     形態：私立
#     評価：4.03
#     口コミ件数：129
#     口コミ（評判）：
#     [{'title': '講義・授業', 'score': 3.96, 'rank': 44}, {'title': '研究室・ゼミ', 'score': 3.85, 'rank': 73}, {'title': '就職・進学', 'score': 4.04, 'rank': 86}, {'title': 'アクセス・立地', 'score': 3.0, 'rank': 274}, {'title': '施設・設備', 'score': 4.01, 'rank': 64}, {'title': '友人・恋愛', 'score': 3.63, 'rank': 232}, {'title': '学生生活', 'score': 3.11, 'rank': 350}]
#     学べる学問：
#     ['国際関係学', '英米語', '日本語', '日本文学', '芸術理論', '被服・服飾学', '食物・栄養学', '社会福祉学', '生活科学', '看護']
#     学費：
#     [{'category': '人文学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 660000, 'gakuhi_upper': 750000}, {'category': '家政学部', 'enrollment_fee_lower': 250000, 'enrollment_fee_upper': 250000, 'gakuhi_lower': 700000, 'gakuhi_upper': 780000}]
#     最寄り駅：国府台駅
#     学部：['人文学部', '家政学部', '看護学部']
#     口コミ順位：61

# %% [markdown]
# Pandasに突っ込む
#
#   name = ''  # 大学名
#   page_url = ''  # 大学情報ページのURL soupで保持
#   hensa_upper = '' # 大学のUpper偏差値
#   hensa_lower = '' # 大学のLower偏差値
#   prefecture = '' # 大学の所在都道府県
#   manage = ''  # 私立・国立など
#
#   個別ページから取得する情報
#   star = 0  # レビューの星の数
#   review_num = 0  # 口コミ件数
#   review_upper = []  # 口コミ（評判）のやつ。カテゴリ、得点、順位で1ペア
#   gakumon = []  # 学べる学問
#   gakuhi = []  # カテゴリ、入学金、年間授業料で1ペア
#   station = ''  # 最寄り駅
#   gakubu = []  # 学部
#   rank = []  # 口コミの順位

# %%
# 充足率抜くやつ
import re

jusoku_url = requests.get('https://tanuki-no-suji.at.webry.info/201811/article_1.html')
jusoku_soup = BeautifulSoup(jusoku_url.content, 'html.parser')

jusoku_all = jusoku_soup.find('td', id="blog-body")

jusoku_dict = {}

for jusoku in jusoku_all.childGenerator():
  if jusoku.__class__ == element.NavigableString and '大学（' in str(jusoku):
    jusoku = re.split('[：（]', str(jusoku))
    
    jusoku_rank = int(jusoku[0][:-1])
    
    jusoku_unv_name = jusoku[1][1:]
    
    jusoku_ritsu = float(jusoku[2][:-1])
    
    jusoku_dict[jusoku_unv_name] = {
        'jusoku_rank' : jusoku_rank,
        'jusoku_ritsu' : jusoku_ritsu
    }

# %%
import pandas as pd

# pandas用リスト
name_list = []
hensa_lower_list = []
hensa_upper_list = []
prefecture_list = []
manage_list = []
star_list = []
review_num_list = []
gakumon_num_list = []
gakubu_num_list = []
rank_list = []
# 充足率関係
jusoku_rank_list = []
jusoku_ritsu_list = []

# Listにつっこむ
for unv in unv_list:
  name_list.append(unv.name)
  hensa_lower_list.append(unv.hensa_lower)
  hensa_upper_list.append(unv.hensa_upper)
  prefecture_list.append(unv.prefecture)
  manage_list.append(unv.manage)
  star_list.append(unv.star)
  review_num_list.append(unv.review_num)
  gakumon_num_list.append(len(unv.gakumon))
  gakubu_num_list.append(len(unv.gakubu))
  rank_list.append(unv.rank)
  try:
    jusoku_rank_list.append(jusoku_dict[unv.name]['jusoku_rank'])
  except KeyError:
    jusoku_rank_list.append('None')
  try:
    jusoku_ritsu_list.append(jusoku_dict[unv.name]['jusoku_ritsu'])
  except KeyError:
    jusoku_ritsu_list.append('None')

# seriesに変換
name_list = pd.Series(name_list)
hensa_lower_list = pd.Series(hensa_lower_list)
hensa_upper_list = pd.Series(hensa_upper_list)
prefecture_list = pd.Series(prefecture_list)
manage_list = pd.Series(manage_list)
star_list = pd.Series(star_list)
review_num_list = pd.Series(review_num_list)
gakumon_num_list = pd.Series(gakumon_num_list)
gakubu_num_list = pd.Series(gakubu_num_list)
rank_list = pd.Series(rank_list)

# DataFrameに格納
unv_all_data = pd.DataFrame({
    'name' : name_list,
    'hensa_lower' : hensa_lower_list,
    'hensa_upper' : hensa_upper_list,
    'prefecture' : prefecture_list,
    'manage' : manage_list,
    'star' : star_list,
    'review_num' : review_num_list,
    # 'review_upper'は一旦保留
    'gakumon_num' : gakumon_num_list,
    'gakubu_num' : gakubu_num_list,
    'rank' : rank_list,
    'jusoku_rank' : jusoku_rank_list,
    'jusoku_ritsu' : jusoku_ritsu_list
})

unv_all_data
# Out:
#      gakubu_num  gakumon_num hensa_lower hensa_upper jusoku_rank jusoku_ritsu  \
# 0             1            3          35          35         608           94
# 1             2            2        52.5          65         465        101.9
# 2             9           18        42.5          50         514        100.2
# 3             2            7           0        37.5         736         64.7
# 4             1            5        47.5        57.5         297        105.7
# 5             2            6          45          55         459        102.1
# 6             5           15          50          55         292        105.8
# 7             1            4           0          35         622         92.4
# 8             3            9          40        52.5         497        100.6
# 9             2            8           0        42.5         293        105.8
# 10            9           25          40          50          19        126.1
# 11            7           21        47.5          55          73        117.4
# 12            3           10          35          35         100        114.9
# 13            1            3           0           0         343        104.5
# 14            1            4           0           0         340        104.6
# 15            1            2          45          45         323          105
# 16            1            4          40          45         206        109.2
# 17            1            4           0           0         210          109
# 18            1            3          45          45         215        108.7
# 19            4            9          35          35         495        100.7
# 20            2            3          35        37.5          32        122.6
# 21           11           32          55          65         590         95.8
# 22            1            2          35        37.5         559         98.9
# 23            2            9        42.5        47.5         281        106.2
# 24            1            1           0           0         323          105
# 25            4           17        42.5          65         250        107.3
# 26            1            2           0          65         515          100
# 27            2            5           0          35         682           82
# 28            4            5          35          40          53        119.7
# 29            2            7        37.5          60          95        115.7
# ..          ...          ...         ...         ...         ...          ...
# 764           6            6          35          40         159        111.2
# 765           3            6           0           0         177        110.4
# 766           4           17        42.5          65         441        102.4
# 767           5           14          55          65         424        102.6
# 768           1            2           0          40          15        128.3
# 769           5           19        67.5        67.5         220        108.6
# 770           2            3           0        37.5         690         80.6
# 771           1            3          35          35         150        111.6
# 772           1            1          45        47.5         113        113.8
# 773           1            1        47.5        47.5         129          113
# 774           3            5          35          35         472        101.7
# 775           2            6          35          60         192        109.9
# 776          10           37          55          65         564         98.2
# 777           8           17          35        52.5         467        101.8
# 778           2            6          50        52.5         337        104.8
# 779          16           43        52.5        62.5         628         91.6
# 780           7           28          40          65         443        102.4
# 781           9           37        42.5        52.5         508        100.4
# 782           5            8        37.5          40         134        112.6
# 783           5            8          35          40         128          113
# 784           1            4          35        37.5         269        106.7
# 785           1            4           0           0         515          100
# 786           2            8          35        47.5          66        118.3
# 787           2            3          65          65         499        100.6
# 788           1            1           0           0        None         None
# 789           4           16        47.5        52.5         350        104.4
# 790           3            9           0        37.5         107        114.1
# 791          13           41        62.5          70         588         96.3
# 792           1            5           0           0         751           48
# 793           3           10           0        42.5         241        107.7
#
#     manage         name prefecture  rank  review_num  star
# 0       私立       愛国学園大学        千葉県  None           4  2.75
# 1       私立       愛知医科大学        愛知県   115          29  3.92
# 2       私立       愛知学院大学        愛知県   231         366  3.77
# 3       私立       愛知学泉大学        愛知県   545          56  3.29
# 4       国立       愛知教育大学        愛知県    50         294  3.85
# 5       公立     愛知県立芸術大学        愛知県    11          41  4.12
# 6       公立       愛知県立大学        愛知県    21         272  4.04
# 7       私立       愛知工科大学        愛知県   553          14  3.25
# 8       私立       愛知工業大学        愛知県   407         124  3.58
# 9       私立       愛知産業大学        愛知県    77          16  3.99
# 10      私立       愛知淑徳大学        愛知県   215         480  3.79
# 11      私立         愛知大学        愛知県   184         466  3.82
# 12      私立       愛知東邦大学        愛知県   485          27  3.46
# 13      私立       愛知文教大学        愛知県  None           2  3.00
# 14      私立      愛知みずほ大学        愛知県   570          16  3.13
# 15      公立         会津大学        福島県    49          30  3.85
# 16      私立         藍野大学        大阪府   515          47  3.39
# 17      公立     青森県立保健大学        青森県     3          63  4.25
# 18      公立       青森公立大学        青森県    64          80  3.74
# 19      私立         青森大学        青森県   551          47  3.27
# 20      私立     青森中央学院大学        青森県   484          33  3.46
# 21      私立       青山学院大学        東京都    91        1060  3.95
# 22      私立     秋田看護福祉大学        秋田県    24          21  4.14
# 23      公立       秋田県立大学        秋田県    63          70  3.75
# 24      公立     秋田公立美術大学        秋田県    80          14  3.47
# 25      国立         秋田大学        秋田県    75         236  3.73
# 26      国立       旭川医科大学        北海道    47          59  3.87
# 27      私立         旭川大学        北海道   357          28  3.64
# 28      私立         朝日大学        岐阜県   286          60  3.71
# 29      私立         麻布大学       神奈川県   151         137  3.87
# ..     ...          ...        ...   ...         ...   ...
# 764     私立       山梨学院大学        山梨県   181          73  3.83
# 765     公立       山梨県立大学        山梨県    32          60  3.95
# 766     国立         山梨大学        山梨県    77         151  3.73
# 767     国立       横浜国立大学       神奈川県    60         404  3.79
# 768     私立       横浜商科大学       神奈川県   536          25  3.33
# 769     公立       横浜市立大学       神奈川県    66         261  3.71
# 770     私立       横浜創英大学       神奈川県   358          25  3.64
# 771     私立       横浜美術大学       神奈川県   264          12  3.74
# 772     私立       横浜薬科大学       神奈川県   365          63  3.63
# 773     私立    四日市看護医療大学        三重県   197          24  3.82
# 774     私立        四日市大学        三重県   147           8  3.88
# 775     私立       酪農学園大学        北海道   223         160  3.78
# 776     私立         立教大学        東京都    66        1115  4.01
# 777     私立         立正大学        東京都   255         383  3.74
# 778     私立  立命館アジア太平洋大学        大分県   171         120  3.84
# 779     私立        立命館大学        京都府   178        1537  3.83
# 780     国立         琉球大学        沖縄県    61         311  3.79
# 781     私立         龍谷大学        京都府   208         787  3.80
# 782     私立       流通科学大学        兵庫県   295          53  3.70
# 783     私立       流通経済大学        茨城県   393          98  3.60
# 784     私立        了徳寺大学        千葉県   428          29  3.55
# 785     私立     ルーテル学院大学        東京都   328          21  3.67
# 786     私立         麗澤大学        千葉県   262          59  3.74
# 787     公立    和歌山県立医科大学       和歌山県    62          40  3.76
# 788     私立      和歌山信愛大学       和歌山県  None           0  0.00
# 789     国立        和歌山大学       和歌山県    57         220  3.81
# 790     私立         和光大学        東京都   373          78  3.62
# 791     私立        早稲田大学        東京都    59        2551  4.03
# 792     私立     稚内北星学園大学        北海道  None           4  4.25
# 793     私立       和洋女子大学        千葉県    61         129  4.03
#
# [794 rows x 12 columns]

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Out:
#     100% |████████████████████████████████| 993kB 20.2MB/s
#   Building wheel for PyDrive (setup.py) ... done

# %%
unv_all_data.to_csv('unv_all_data.csv')

upload_file = drive.CreateFile()
upload_file.SetContentFile('unv_all_data.csv')
upload_file.Upload()
